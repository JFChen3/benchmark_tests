# %% [markdown]
# # Predicting Formation Energies using *Ward 2016* and *Deml

# %%
import numpy as np
import matplotlib.pyplot as plt
import re
import itertools
import pandas as pd
import matminer

# %matplotlib inline

# %%
training_set = pd.read_csv("deml_dataset.csv")
training_set
# Out:
#              composition   delta_e
# 0                  As1Y1 -1.555732
# 1                  Ga1P1 -0.534169
# 2               Ga2Mg1S4 -1.068504
# 3             Cd4K1O12V3 -1.968765
# 4     Al1Ca1Fe1Na1O12Si4 -2.949067
# 5               Hf1O3Pb1 -2.830320
# 6        Al2Ba2Co1F14Mn1 -3.488390
# 7        Ba2Cd1F14Fe2Mn1 -3.007836
# 8               Be2O4Si1 -3.020793
# 9        Ba2Ca1Cu1F14Ga2 -3.325601
# 10              Ge1O4Zn2 -1.809053
# 11           Ca1Cr1F7Sr1 -3.707430
# 12             As3Ga1Na6 -0.523152
# 13              Ga1Na6P3 -0.548523
# 14       Al2Ba2Cu1F14Mn1 -3.463375
# 15              O4Si1Zn2 -2.286625
# 16              Al2Ca1O4 -3.293900
# 17           K3Nb3O13Si2 -2.818445
# 18                Ga1Sb1 -0.167088
# 19              Ba1O4Sc2 -3.534127
# 20          Ge3Na4O12Zr2 -2.477888
# 21          Ba3In2O11Zn5 -2.038818
# 22             Ba1Mn1Sb2 -0.452687
# 23              Ge4O9Sr1 -2.158955
# 24           Ba1Co1O4Si1 -2.518078
# 25           Ge2K3Nb3O13 -2.469440
# ...

# %%
from matminer.descriptors import composition as cp
from pymatgen import Composition

import time
start = time.time()
def calc_attributes(training_set):
    training_set_updated = cp.StoichiometricAttribute().featurize_all(training_set)
    training_set_updated = cp.ElementalAttribute().featurize_all(training_set_updated)
    training_set_updated = cp.ValenceOrbitalAttribute().featurize_all(training_set_updated)
    training_set_updated = cp.IonicAttribute().featurize_all(training_set_updated)
    
    return training_set_updated

#%lprun -f calc_attributes calc_attributes()

all_descriptors = calc_attributes(training_set)
print np.shape(all_descriptors)
print "Featurization time: %f "%(time.time() - start)
# Out:
# (2338, 147)
# Featurization time: 4.917596

# %%
cols_to_drop = ["composition", "delta_e"]

# %%
#Discretize into positive/negative formation energy

delta_e = np.array(training_set["delta_e"], dtype=float)
energy_range = np.zeros(np.shape(delta_e), dtype=str)

for i in range(len(delta_e)):
    if delta_e[i] < 0:
        energy_range[i] = "neg"
    else:
        energy_range[i] = "pos"
        
print energy_range
# Out:
# ['n' 'n' 'n' ..., 'p' 'n' 'n']

# %%
from sklearn.ensemble import RandomForestClassifier

model1 = RandomForestClassifier()
model1.fit(all_descriptors.drop(cols_to_drop, axis=1), energy_range)
prediction = model1.predict(all_descriptors.drop(cols_to_drop, axis=1))

# %%
pd.crosstab(energy_range, prediction, rownames=["actual"], colnames=["predicted"])
# Out:
# predicted     n   p
# actual
# n          2323   0
# p             2  13

# %%
from sklearn.ensemble import RandomForestRegressor

rf_model = RandomForestRegressor()
rf_model.fit(all_descriptors.drop(cols_to_drop, axis=1), delta_e)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_split=1e-07, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=10, n_jobs=1, oob_score=False, random_state=None,
#            verbose=0, warm_start=False)

# %%
prediction = rf_model.predict(all_descriptors.drop(cols_to_drop, axis=1))

# %%
plt.scatter(delta_e, prediction)
plt.plot(range(-5,3), range(-5,3), 'r')
#plt.axis([-20,20,-20,20])
plt.xlabel("OQMD Data")
plt.ylabel("Ward Method Prediction")

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold

errors = cross_val_score(RandomForestRegressor(), all_descriptors.drop(cols_to_drop, axis=1), delta_e, scoring="neg_mean_absolute_error", cv=20)
mae = np.mean(np.abs(errors))

print mae
# Out:
# 0.116950156456

# %%
np.mean(np.abs(delta_e-prediction))
# Out:
# 0.045952816931375519

# %% [markdown]
# ## Compare to Model 1 from Deml et. al 2015

# %%
dHf_deml = pd.read_csv("deml_predictions.csv")
dHf_deml
# Out:
#              composition       dHf
# 0                  As1Y1 -1.616769
# 1                  Ga1P1 -0.169276
# 2               Ga2Mg1S4 -1.257402
# 3             Cd4K1O12V3 -2.094023
# 4     Al1Ca1Fe1Na1O12Si4       NaN
# 5               Hf1O3Pb1 -2.537457
# 6        Al2Ba2Co1F14Mn1       NaN
# 7        Ba2Cd1F14Fe2Mn1       NaN
# 8               Be2O4Si1 -3.433094
# 9        Ba2Ca1Cu1F14Ga2 -3.155456
# 10              Ge1O4Zn2 -1.984194
# 11           Ca1Cr1F7Sr1 -3.332806
# 12             As3Ga1Na6 -0.515935
# 13              Ga1Na6P3 -0.563828
# 14       Al2Ba2Cu1F14Mn1       NaN
# 15              O4Si1Zn2 -2.380618
# 16              Al2Ca1O4 -3.384924
# 17           K3Nb3O13Si2       NaN
# 18                Ga1Sb1 -0.214190
# 19              Ba1O4Sc2 -3.684542
# 20          Ge3Na4O12Zr2 -2.539270
# 21          Ba3In2O11Zn5 -2.329107
# 22             Ba1Mn1Sb2 -0.731933
# 23              Ge4O9Sr1 -2.268353
# 24           Ba1Co1O4Si1       NaN
# 25           Ge2K3Nb3O13       NaN
# ...

# %%
dHf_deml = dHf_deml.assign(oqmd_data=delta_e, ward_npj=prediction)

# %%
dHf_deml = dHf_deml.dropna()

# %%
dHf_deml
# Out:
#           composition       dHf  oqmd_data  ward_npj
# 0               As1Y1 -1.616769  -1.555732 -1.439830
# 1               Ga1P1 -0.169276  -0.534169 -0.418096
# 2            Ga2Mg1S4 -1.257402  -1.068504 -1.049889
# 3          Cd4K1O12V3 -2.094023  -1.968765 -2.134571
# 5            Hf1O3Pb1 -2.537457  -2.830320 -2.717580
# 8            Be2O4Si1 -3.433094  -3.020793 -3.009244
# 9     Ba2Ca1Cu1F14Ga2 -3.155456  -3.325601 -3.336792
# 10           Ge1O4Zn2 -1.984194  -1.809053 -1.784987
# 11        Ca1Cr1F7Sr1 -3.332806  -3.707430 -3.707574
# 12          As3Ga1Na6 -0.515935  -0.523152 -0.521644
# 13           Ga1Na6P3 -0.563828  -0.548523 -0.547656
# 15           O4Si1Zn2 -2.380618  -2.286625 -2.206644
# 16           Al2Ca1O4 -3.384924  -3.293900 -3.291337
# 18             Ga1Sb1 -0.214190  -0.167088 -0.225697
# 19           Ba1O4Sc2 -3.684542  -3.534127 -3.503602
# 20       Ge3Na4O12Zr2 -2.539270  -2.477888 -2.420944
# 21       Ba3In2O11Zn5 -2.329107  -2.038818 -2.094690
# ...

# %%
plt.scatter(dHf_deml["oqmd_data"], dHf_deml["dHf"])
plt.plot(range(-5,3), range(-5,3), 'r')
plt.xlabel("OQMD Data")
plt.ylabel("Deml Model 1 Prediction")

# %%
np.mean(np.abs(dHf_deml["dHf"]-dHf_deml["oqmd_data"]))
# Out:
# 0.13436403065486335

# %%
plt.scatter(dHf_deml["dHf"], dHf_deml["ward_npj"])
plt.plot(range(-5,3), range(-5,3), 'r')
plt.xlabel("Deml Model 1 Prediction")
plt.ylabel("Ward Method Prediction")

# %%
np.mean(np.abs(dHf_deml["dHf"]-dHf_deml["ward_npj"]))
# Out:
# 0.1401905924495395
