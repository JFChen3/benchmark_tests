# %% [markdown]
# # Formation Energy Prediction using *Deml 2016* Descriptors
#
# This notebook uses the method from [Deml 2016](https://journals.aps.org/prb/abstract/10.1103/PhysRevB.93.085142) to predict formation energy of compounds. Specifically, it uses the set of composition based attributes described in the paper to train a machine learning model.

# %%
training_file = 'datasets/deml_dataset.csv'
delimiter = ','
comp_col = 'composition'

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import matminer

from pymatgen import Composition
from matminer.featurizers import composition as cp
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor
from sklearn.model_selection import cross_val_score, KFold

# %matplotlib inline

# %% [markdown]
# ## Load input files and generate descriptors
# The training set is a set of ~2000 compounds with data extracted from the Open Quantum Materials Database (OQMD)

# %%
def load_training_set(files, sep):
    """Function to read data files and load them into a Pandas DataFrame"""
        
    if type(files) is not list:
        training_set = pd.read_csv(files, sep=sep)
    else:
        training_set = pd.DataFrame()
        for i in range(len(files)):
            training_set.append(pd.read_csv(files[i], sep=sep[i]))

    return training_set

training_set = load_training_set(training_file, delimiter)

# %% [markdown]
# ### Create PyMatGen composition objects

# %%
comp_objects = [Composition(comp) for comp in training_set[comp_col]]
comp_objects
training_set = training_set.assign(comp_obj=comp_objects)
training_set
# Out:
#              composition   delta_e                 comp_obj
# 0                  As1Y1 -1.555732                  (As, Y)
# 1                  Ga1P1 -0.534169                  (Ga, P)
# 2               Ga2Mg1S4 -1.068504              (S, Mg, Ga)
# 3             Cd4K1O12V3 -1.968765            (O, Cd, K, V)
# 4     Al1Ca1Fe1Na1O12Si4 -2.949067  (O, Na, Al, Si, Ca, Fe)
# 5               Hf1O3Pb1 -2.830320              (Hf, O, Pb)
# 6        Al2Ba2Co1F14Mn1 -3.488390      (Ba, F, Co, Al, Mn)
# 7        Ba2Cd1F14Fe2Mn1 -3.007836      (Ba, F, Fe, Cd, Mn)
# 8               Be2O4Si1 -3.020793              (O, Be, Si)
# 9        Ba2Ca1Cu1F14Ga2 -3.325601      (Ba, F, Ca, Cu, Ga)
# 10              Ge1O4Zn2 -1.809053              (Ge, O, Zn)
# 11           Ca1Cr1F7Sr1 -3.707430          (Cr, F, Ca, Sr)
# 12             As3Ga1Na6 -0.523152             (As, Na, Ga)
# 13              Ga1Na6P3 -0.548523              (P, Na, Ga)
# 14       Al2Ba2Cu1F14Mn1 -3.463375      (Ba, Mn, Cu, Al, F)
# 15              O4Si1Zn2 -2.286625              (O, Zn, Si)
# 16              Al2Ca1O4 -3.293900              (O, Ca, Al)
# 17           K3Nb3O13Si2 -2.818445           (O, Nb, K, Si)
# 18                Ga1Sb1 -0.167088                 (Sb, Ga)
# 19              Ba1O4Sc2 -3.534127              (Ba, O, Sc)
# 20          Ge3Na4O12Zr2 -2.477888          (Ge, Zr, Na, O)
# 21          Ba3In2O11Zn5 -2.038818          (Ba, O, Zn, In)
# 22             Ba1Mn1Sb2 -0.452687             (Ba, Mn, Sb)
# 23              Ge4O9Sr1 -2.158955              (Ge, O, Sr)
# 24           Ba1Co1O4Si1 -2.518078          (Ba, O, Co, Si)
# 25           Ge2K3Nb3O13 -2.469440           (O, Ge, K, Nb)
# 26           Ba1Mg1O4Si1 -3.156372          (Ba, O, Mg, Si)
# 27          Na2O13Si4Ti2 -2.994975          (O, Na, Ti, Si)
# 28             Ba2Cu5F14 -2.422743              (Ba, F, Cu)
# 29           Ba1O4Si1Zn1 -2.780893          (Ba, O, Si, Zn)
# ...                  ...       ...                      ...
# 2308         Ba1Ca1F7Ga1 -3.705833          (Ba, F, Ca, Ga)
# 2309         Ba1F7Fe1Mn1 -3.028555          (Ba, Mn, Fe, F)
# 2310          In1K3Na2O4 -1.555390           (K, O, Na, In)
# 2311         Mg4Na1O12V3 -2.663958           (O, Na, Mg, V)
# 2312            Be1Na2O2 -2.117752              (O, Na, Be)
# 2313         Ba1Ca1Cr1F7 -3.708148          (Cr, Ba, Ca, F)
# 2314         Ba1F7Na1Zr1 -3.894199          (Ba, Zr, Na, F)
# 2315          Al1Mo1O7V1 -2.527260           (O, Mo, Al, V)
# 2316             Cu1F3K1 -2.326135               (F, K, Cu)
# 2317            Al1Ca2F7 -4.070533              (F, Ca, Al)
# 2318          Cu1F7Hf1K1 -3.213797           (Hf, F, K, Cu)
# 2319             F3K1Sn1 -2.769554               (F, Sn, K)
# 2320            Cl6In1K3 -1.878524              (In, K, Cl)
# 2321            O3Pb1Zr1 -2.688863              (Zr, O, Pb)
# 2322         Ba1Cd1F7Ga1 -3.177542          (Ba, F, Cd, Ga)
# 2323            Al1Fe1O3 -2.451067              (O, Fe, Al)
# 2324            Cr1F7Pb2 -2.763725              (Cr, F, Pb)
# 2325        Ca1Cu3O12Ti4 -2.555322          (O, Ca, Cu, Ti)
# 2326             Hf1O7V2 -2.804765               (Hf, O, V)
# 2327            Mg1O3Si1 -3.074223              (O, Mg, Si)
# 2328            Fe1O3Zr1 -2.695420              (Zr, O, Fe)
# 2329          F7K1Sn1Zr1 -3.405506           (Zr, F, Sn, K)
# 2330               Cd3P2 -0.158201                  (Cd, P)
# 2331            Ag1Nb1O3 -2.019452              (O, Nb, Ag)
# 2332              Al2Te3 -0.450581                 (Te, Al)
# 2333               Be3P2 -0.332600                  (Be, P)
# 2334            Mo1Na4O5 -2.109603              (O, Mo, Na)
# 2335               Cd3N2  0.464897                  (Cd, N)
# 2336         Al1Ba1Ca1F7 -4.077008          (Ba, F, Ca, Al)
# 2337             O7V2Zr1 -2.733333               (Zr, O, V)
#
# [2338 rows x 3 columns]

# %% [markdown]
# ## Compute descriptors using MatMiner
# Here, we compute composition based attributes as described in *Deml 2016* using the [MatMiner](https://github.com/hackingmaterials/matminer) implementation of the featurizer.

# %%
# %%time

def calc_attributes(training_set):
    not_attr = list(training_set) #Non-attribute columns
    training_set_updated = cp.Stoichiometry(p_list=None, num_atoms=True).featurize_dataframe(training_set, col_id="comp_obj")
    training_set_updated = cp.ElementProperty(method="deml").featurize_dataframe(training_set_updated, col_id="comp_obj")
    training_set_updated = cp.ValenceOrbital(orbitals=["s","p","d"], props=["avg","frac"]).featurize_dataframe(training_set_updated, col_id="comp_obj")
    training_set_updated = cp.TMetalFraction().featurize_dataframe(training_set_updated, col_id="comp_obj")
    training_set_updated = cp.ElectronAffinity().featurize_dataframe(training_set_updated, col_id="comp_obj")
    training_set_updated = cp.ElectronegativityDiff().featurize_dataframe(training_set_updated, col_id="comp_obj")
    training_set_updated = cp.FERECorrection().featurize_dataframe(training_set_updated, col_id="comp_obj")
    all_cols = list(training_set_updated)
    attr_names = [col for col in all_cols if col not in not_attr]
    return training_set_updated, attr_names

all_descriptors, attr_names = calc_attributes(training_set)
# Out:
# CPU times: user 5.59 s, sys: 27.7 ms, total: 5.62 s
# Wall time: 5.61 s

# %% [markdown]
# ## Predicting formation energy

# %%
training_set_use = all_descriptors.replace("None", np.nan)
training_set_use = all_descriptors.replace(np.inf, np.nan)
training_set_use = training_set_use.dropna()

training_set_use
# Out:
#              composition   delta_e                 comp_obj  Number of atoms  \
# 0                  As1Y1 -1.555732                  (As, Y)              2.0
# 1                  Ga1P1 -0.534169                  (Ga, P)              2.0
# 2               Ga2Mg1S4 -1.068504              (S, Mg, Ga)              7.0
# 3             Cd4K1O12V3 -1.968765            (O, Cd, K, V)             20.0
# 4     Al1Ca1Fe1Na1O12Si4 -2.949067  (O, Na, Al, Si, Ca, Fe)             20.0
# 6        Al2Ba2Co1F14Mn1 -3.488390      (Ba, F, Co, Al, Mn)             20.0
# 7        Ba2Cd1F14Fe2Mn1 -3.007836      (Ba, F, Fe, Cd, Mn)             20.0
# 8               Be2O4Si1 -3.020793              (O, Be, Si)              7.0
# 9        Ba2Ca1Cu1F14Ga2 -3.325601      (Ba, F, Ca, Cu, Ga)             20.0
# 10              Ge1O4Zn2 -1.809053              (Ge, O, Zn)              7.0
# 11           Ca1Cr1F7Sr1 -3.707430          (Cr, F, Ca, Sr)             10.0
# 12             As3Ga1Na6 -0.523152             (As, Na, Ga)             10.0
# 13              Ga1Na6P3 -0.548523              (P, Na, Ga)             10.0
# 14       Al2Ba2Cu1F14Mn1 -3.463375      (Ba, Mn, Cu, Al, F)             20.0
# 15              O4Si1Zn2 -2.286625              (O, Zn, Si)              7.0
# 16              Al2Ca1O4 -3.293900              (O, Ca, Al)              7.0
# 17           K3Nb3O13Si2 -2.818445           (O, Nb, K, Si)             21.0
# 18                Ga1Sb1 -0.167088                 (Sb, Ga)              2.0
# 19              Ba1O4Sc2 -3.534127              (Ba, O, Sc)              7.0
# 20          Ge3Na4O12Zr2 -2.477888          (Ge, Zr, Na, O)             21.0
# 21          Ba3In2O11Zn5 -2.038818          (Ba, O, Zn, In)             21.0
# 22             Ba1Mn1Sb2 -0.452687             (Ba, Mn, Sb)              4.0
# 23              Ge4O9Sr1 -2.158955              (Ge, O, Sr)             14.0
# 24           Ba1Co1O4Si1 -2.518078          (Ba, O, Co, Si)              7.0
# 25           Ge2K3Nb3O13 -2.469440           (O, Ge, K, Nb)             21.0
# 26           Ba1Mg1O4Si1 -3.156372          (Ba, O, Mg, Si)              7.0
# 27          Na2O13Si4Ti2 -2.994975          (O, Na, Ti, Si)             21.0
# 28             Ba2Cu5F14 -2.422743              (Ba, F, Cu)             21.0
# 29           Ba1O4Si1Zn1 -2.780893          (Ba, O, Si, Zn)              7.0
# 32                As1Ga1 -0.352948                 (As, Ga)              2.0
# ...                  ...       ...                      ...              ...
# 2306         Ba1F7Fe1Zn1 -3.007388          (Ba, F, Fe, Zn)             10.0
# 2307            F7In1Sr2 -3.653277              (In, Sr, F)             10.0
# 2308         Ba1Ca1F7Ga1 -3.705833          (Ba, F, Ca, Ga)             10.0
# 2309         Ba1F7Fe1Mn1 -3.028555          (Ba, Mn, Fe, F)             10.0
# 2310          In1K3Na2O4 -1.555390           (K, O, Na, In)             10.0
# 2311         Mg4Na1O12V3 -2.663958           (O, Na, Mg, V)             20.0
# 2312            Be1Na2O2 -2.117752              (O, Na, Be)              5.0
# 2313         Ba1Ca1Cr1F7 -3.708148          (Cr, Ba, Ca, F)             10.0
# 2314         Ba1F7Na1Zr1 -3.894199          (Ba, Zr, Na, F)             10.0
# 2315          Al1Mo1O7V1 -2.527260           (O, Mo, Al, V)             10.0
# 2316             Cu1F3K1 -2.326135               (F, K, Cu)              5.0
# 2317            Al1Ca2F7 -4.070533              (F, Ca, Al)             10.0
# 2318          Cu1F7Hf1K1 -3.213797           (Hf, F, K, Cu)             10.0
# 2319             F3K1Sn1 -2.769554               (F, Sn, K)              5.0
# 2320            Cl6In1K3 -1.878524              (In, K, Cl)             10.0
# 2322         Ba1Cd1F7Ga1 -3.177542          (Ba, F, Cd, Ga)             10.0
# 2323            Al1Fe1O3 -2.451067              (O, Fe, Al)              5.0
# 2325        Ca1Cu3O12Ti4 -2.555322          (O, Ca, Cu, Ti)             20.0
# 2326             Hf1O7V2 -2.804765               (Hf, O, V)             10.0
# 2327            Mg1O3Si1 -3.074223              (O, Mg, Si)              5.0
# 2328            Fe1O3Zr1 -2.695420              (Zr, O, Fe)              5.0
# 2329          F7K1Sn1Zr1 -3.405506           (Zr, F, Sn, K)             10.0
# 2330               Cd3P2 -0.158201                  (Cd, P)              5.0
# 2331            Ag1Nb1O3 -2.019452              (O, Nb, Ag)              5.0
# 2332              Al2Te3 -0.450581                 (Te, Al)              5.0
# 2333               Be3P2 -0.332600                  (Be, P)              5.0
# 2334            Mo1Na4O5 -2.109603              (O, Mo, Na)             10.0
# 2335               Cd3N2  0.464897                  (Cd, N)              5.0
# 2336         Al1Ba1Ca1F7 -4.077008          (Ba, F, Ca, Al)             10.0
# 2337             O7V2Zr1 -2.733333               (Zr, O, V)             10.0
#
#       maximum GGAU_Etot  maximum atom_mass  maximum atom_num  \
# 0                 -4.65          88.905850              39.0
# 1                 -3.03          69.723000              31.0
# 2                 -1.54          69.723000              31.0
# 3                 -0.91         112.411000              48.0
# 4                 -1.23          55.845000              26.0
# 6                 -1.86         137.327000              56.0
# 7                 -0.91         137.327000              56.0
# 8                 -3.75          28.085500              14.0
# 9                 -1.86         137.327000              56.0
# 10                -1.27          72.640000              32.0
# 11                -1.68          87.620000              38.0
# 12                -1.23          74.921600              33.0
# 13                -1.23          69.723000              31.0
# 14                -1.86         137.327000              56.0
# 15                -1.27          65.380000              30.0
# 16                -1.93          40.078000              20.0
# 17                -1.08          92.906380              41.0
# 18                -3.03         121.760000              51.0
# 19                -1.93         137.327000              56.0
# 20                -1.23          91.224000              40.0
# 21                -1.27         137.327000              56.0
# 22                -1.93         137.327000              56.0
# 23                -1.68          87.620000              38.0
# 24                -1.93         137.327000              56.0
# 25                -1.08          92.906380              41.0
# 26                -1.54         137.327000              56.0
# 27                -1.23          47.867000              22.0
# 28                -1.86         137.327000              56.0
# 29                -1.27         137.327000              56.0
# 32                -3.03          74.921600              33.0
# ...                 ...                ...               ...
# 2306              -1.27         137.327000              56.0
# 2307              -1.68         114.818000              49.0
# 2308              -1.86         137.327000              56.0
# 2309              -1.86         137.327000              56.0
# 2310              -1.08         114.818000              49.0
# 2311              -1.23          50.941500              23.0
# 2312              -1.23          22.989769              11.0
# 2313              -1.86         137.327000              56.0
# 2314              -1.23         137.327000              56.0
# 2315              -3.74          95.960000              42.0
# 2316              -1.08          63.546000              29.0
# 2317              -1.86          40.078000              20.0
# 2318              -1.08         178.490000              72.0
# 2319              -1.08         118.710000              50.0
# 2320              -1.08         114.818000              49.0
# 2322              -0.91         137.327000              56.0
# 2323              -3.74          55.845000              26.0
# 2325              -1.93          63.546000              29.0
# 2326              -4.99         178.490000              72.0
# 2327              -1.54          28.085500              14.0
# 2328              -4.99          91.224000              40.0
# 2329              -1.08         118.710000              50.0
# 2330              -0.91         112.411000              48.0
# 2331              -0.71         107.868200              47.0
# 2332              -3.14         127.600000              52.0
# 2333              -3.75          30.973762              15.0
# 2334              -1.23          95.960000              42.0
# 2335              -0.91         112.411000              48.0
# 2336              -1.86         137.327000              56.0
# 2337              -4.99          91.224000              40.0
#
#       maximum atom_radius  maximum boiling_point  maximum col_num  \
# 0                   180.0                 3609.0             15.0
# 1                   130.0                 2477.0             15.0
# 2                   150.0                 2477.0             16.0
# 3                   220.0                 3680.0             16.0
# 4                   180.0                 3173.0             16.0
# 6                   215.0                 3200.0             17.0
# 7                   215.0                 3134.0             17.0
# 8                   110.0                 3173.0             16.0
# 9                   215.0                 3200.0             17.0
# 10                  135.0                 3093.0             16.0
# 11                  200.0                 2944.0             17.0
# 12                  180.0                 2477.0             15.0
# 13                  180.0                 2477.0             15.0
# 14                  215.0                 3200.0             17.0
# 15                  135.0                 3173.0             16.0
# 16                  180.0                 2792.0             16.0
# 17                  220.0                 5017.0             16.0
# 18                  145.0                 2477.0             15.0
# 19                  215.0                 3103.0             16.0
# 20                  180.0                 4682.0             16.0
# 21                  215.0                 2345.0             16.0
# 22                  215.0                 2334.0             15.0
# 23                  200.0                 3093.0             16.0
# 24                  215.0                 3200.0             16.0
# 25                  220.0                 5017.0             16.0
# 26                  215.0                 3173.0             16.0
# 27                  180.0                 3560.0             16.0
# 28                  215.0                 3200.0             17.0
# 29                  215.0                 3173.0             16.0
# 32                  130.0                 2477.0             15.0
# ...                   ...                    ...              ...
# 2306                215.0                 3134.0             17.0
# 2307                200.0                 2345.0             17.0
# 2308                215.0                 2477.0             17.0
# 2309                215.0                 3134.0             17.0
# 2310                220.0                 2345.0             16.0
# 2311                180.0                 3680.0             16.0
# 2312                180.0                 2742.0             16.0
# 2313                215.0                 2944.0             17.0
# 2314                215.0                 4682.0             17.0
# 2315                145.0                 4912.0             16.0
# 2316                220.0                 3200.0             17.0
# 2317                180.0                 2792.0             17.0
# 2318                220.0                 4876.0             17.0
# 2319                220.0                 2875.0             17.0
# 2320                220.0                 2345.0             17.0
# 2322                215.0                 2477.0             17.0
# 2323                140.0                 3134.0             16.0
# 2325                180.0                 3560.0             16.0
# 2326                155.0                 4876.0             16.0
# 2327                150.0                 3173.0             16.0
# 2328                155.0                 4682.0             16.0
# 2329                220.0                 4682.0             17.0
# 2330                155.0                 1040.0             15.0
# 2331                160.0                 5017.0             16.0
# 2332                140.0                 2792.0             16.0
# 2333                105.0                 2742.0             15.0
# 2334                180.0                 4912.0             16.0
# 2335                155.0                 1040.0             15.0
# 2336                215.0                 2792.0             17.0
# 2337                155.0                 4682.0             16.0
#
#                ...             maximum EN difference  mean EN difference  \
# 0              ...                              0.96            0.960000
# 1              ...                              0.38            0.380000
# 2              ...                              1.27            0.936667
# 3              ...                              2.62            1.881250
# 4              ...                              2.51            1.818750
# 6              ...                              3.09            2.575000
# 7              ...                              3.09            2.533333
# 8              ...                              1.87            1.760000
# 9              ...                              3.09            2.596667
# 10             ...                              1.79            1.670000
# 11             ...                              3.03            2.776667
# 12             ...                              1.25            1.124286
# 13             ...                              1.26            1.134286
# 14             ...                              3.09            2.571667
# 15             ...                              1.79            1.706667
# 16             ...                              2.44            2.033333
# 17             ...                              2.62            2.057500
# 18             ...                              0.24            0.240000
# 19             ...                              2.55            2.236667
# 20             ...                              2.51            2.061111
# 21             ...                              2.55            1.992000
# 22             ...                              1.16            0.830000
# 23             ...                              2.49            1.642000
# 24             ...                              2.55            1.883333
# 25             ...                              2.62            2.030000
# 26             ...                              2.55            2.073333
# 27             ...                              2.51            1.872500
# 28             ...                              3.09            2.368571
# 29             ...                              2.55            1.960000
# 32             ...                              0.37            0.370000
# ...            ...                               ...                 ...
# 2306           ...                              3.09            2.523333
# 2307           ...                              3.03            2.753333
# 2308           ...                              3.09            2.746667
# 2309           ...                              3.09            2.556667
# 2310           ...                              2.62            2.423333
# 2311           ...                              2.51            2.057500
# 2312           ...                              2.51            2.296667
# 2313           ...                              3.09            2.796667
# 2314           ...                              3.09            2.930000
# 2315           ...                              1.83            1.640000
# 2316           ...                              3.16            2.620000
# 2317           ...                              2.98            2.776667
# 2318           ...                              3.16            2.640000
# 2319           ...                              3.16            2.590000
# 2320           ...                              2.34            2.100000
# 2322           ...                              3.09            2.516667
# 2323           ...                              1.83            1.720000
# 2325           ...                              2.44            1.832500
# 2326           ...                              2.14            1.920000
# 2327           ...                              2.13            1.835000
# 2328           ...                              2.11            1.860000
# 2329           ...                              3.16            2.610000
# 2330           ...                              0.50            0.500000
# 2331           ...                              1.84            1.675000
# 2332           ...                              0.49            0.490000
# 2333           ...                              0.62            0.620000
# 2334           ...                              2.51            2.264000
# 2335           ...                              1.35            1.350000
# 2336           ...                              3.09            2.813333
# 2337           ...                              2.11            1.910000
#
#       minimum EN difference  range EN difference  std_dev EN difference  \
# 0                      0.96                 0.00               0.000000
# 1                      0.38                 0.00               0.000000
# 2                      0.77                 0.50               0.250000
# 3                      1.75                 0.87               0.396737
# 4                      1.54                 0.97               0.411174
# 6                      2.10                 0.99               0.363963
# 7                      2.15                 0.94               0.360278
# 8                      1.54                 0.33               0.165000
# 9                      2.08                 1.01               0.457766
# 10                     1.43                 0.36               0.180000
# 11                     2.32                 0.71               0.323557
# 12                     0.37                 0.88               0.440000
# 13                     0.38                 0.88               0.440000
# 14                     2.08                 1.01               0.369484
# 15                     1.54                 0.25               0.125000
# 16                     1.83                 0.61               0.305000
# 17                     1.54                 1.08               0.455192
# 18                     0.24                 0.00               0.000000
# 19                     2.08                 0.47               0.235000
# 20                     1.43                 1.08               0.445820
# 21                     1.66                 0.89               0.392513
# 22                     0.50                 0.66               0.330000
# 23                     1.43                 1.06               0.530000
# 24                     1.54                 1.01               0.471475
# 25                     1.43                 1.19               0.493581
# 26                     1.54                 1.01               0.414273
# 27                     1.54                 0.97               0.400361
# 28                     2.08                 1.01               0.505000
# 29                     1.54                 1.01               0.429496
# 32                     0.37                 0.00               0.000000
# ...                     ...                  ...                    ...
# 2306                   2.15                 0.94               0.407376
# 2307                   2.20                 0.83               0.415000
# 2308                   2.17                 0.92               0.410230
# 2309                   2.15                 0.94               0.394067
# 2310                   1.66                 0.96               0.428978
# 2311                   1.81                 0.70               0.286124
# 2312                   1.87                 0.64               0.320000
# 2313                   2.32                 0.77               0.340033
# 2314                   2.65                 0.44               0.198662
# 2315                   1.28                 0.55               0.254689
# 2316                   2.08                 1.08               0.540000
# 2317                   2.37                 0.61               0.305000
# 2318                   2.08                 1.08               0.441814
# 2319                   2.02                 1.14               0.570000
# 2320                   1.38                 0.96               0.480000
# 2322                   2.17                 0.92               0.408357
# 2323                   1.61                 0.22               0.110000
# 2325                   1.54                 0.90               0.369865
# 2326                   1.81                 0.33               0.165000
# 2327                   1.54                 0.59               0.295000
# 2328                   1.61                 0.50               0.250000
# 2329                   2.02                 1.14               0.466262
# 2330                   0.50                 0.00               0.000000
# 2331                   1.51                 0.33               0.165000
# 2332                   0.49                 0.00               0.000000
# 2333                   0.62                 0.00               0.000000
# 2334                   1.28                 1.23               0.615000
# 2335                   1.35                 0.00               0.000000
# 2336                   2.37                 0.72               0.316684
# 2337                   1.81                 0.30               0.150000
#
#       maximum FERE Correction  mean FERE Correction  minimum FERE Correction  \
# 0                    0.667379              0.128689                -0.410000
# 1                    0.660000             -0.010000                -0.680000
# 2                    0.660000              0.301429                 0.060000
# 3                    0.350000              0.153955                -0.451973
# 4                    0.720000              0.274637                -0.152134
# 6                    0.720000              0.228353                -0.104349
# 7                    0.535501              0.163857                -0.152134
# 8                    0.427225              0.293258                 0.230000
# 9                    0.660000              0.246270                 0.057419
# 10                   0.430000              0.276080                 0.152561
# 11                   0.512544              0.196362                 0.067585
# 12                   0.660000              0.042580                -0.410000
# 13                   0.660000             -0.038420                -0.680000
# 14                   0.720000              0.236441                -0.026578
# 15                   0.430000              0.315318                 0.230000
# 16                   0.720000              0.378571                 0.230000
# 17                   0.427225              0.272820                 0.230000
# 18                   0.660000              0.246887                -0.166226
# 19                   0.535501              0.347859                 0.230000
# 20                   0.725294              0.253911                 0.152561
# 21                   0.535501              0.338405                 0.230000
# 22                   0.535501              0.044118                -0.166226
# 23                   0.512544              0.228056                 0.152561
# 24                   0.535501              0.254054                -0.104349
# 25                   0.353248              0.246661                 0.152561
# 26                   0.550000              0.347532                 0.230000
# 27                   0.427225              0.244632                 0.053216
# 28                   0.535501              0.168813                 0.057419
# 29                   0.535501              0.330389                 0.230000
# 32                   0.660000              0.125000                -0.410000
# ...                       ...                   ...                      ...
# 2306                 0.535501              0.190686                -0.152134
# 2307                 0.512544              0.252858                 0.156213
# 2308                 0.660000              0.257899                 0.156213
# 2309                 0.535501              0.145028                -0.152134
# 2310                 0.410000              0.248696                 0.165967
# 2311                 0.550000              0.188502                -0.451973
# 2312                 0.352791              0.228945                 0.165967
# 2313                 0.535501              0.198658                 0.067585
# 2314                 0.725294              0.252026                 0.156213
# 2315                 0.720000              0.164343                -0.451973
# 2316                 0.275008              0.160213                 0.057419
# 2317                 0.720000              0.239349                 0.156213
# 2318                 0.722304              0.214822                 0.057419
# 2319                 0.275008              0.184831                 0.156213
# 2320                 0.410000              0.221756                 0.163756
# 2322                 0.660000              0.263899                 0.156213
# 2323                 0.720000              0.251573                -0.152134
# 2325                 0.290000              0.171756                 0.053216
# 2326                 0.722304              0.142836                -0.451973
# 2327                 0.550000              0.333445                 0.230000
# 2328                 0.725294              0.252632                -0.152134
# 2329                 0.725294              0.227430                 0.156213
# 2330                 0.350000             -0.062000                -0.680000
# 2331                 0.353248              0.185248                -0.117010
# 2332                 0.720000              0.221796                -0.110341
# 2333                 0.352791             -0.060326                -0.680000
# 2334                 0.230000              0.157927                -0.234600
# 2335                 0.350000              0.130000                -0.200000
# 2336                 0.720000              0.263899                 0.156213
# 2337                 0.725294              0.143135                -0.451973
#
#       range FERE Correction  std_dev FERE Correction
# 0                  1.077379                 0.538689
# 1                  1.340000                 0.670000
# 2                  0.600000                 0.280837
# 3                  0.801973                 0.258769
# 4                  0.872134                 0.159620
# 6                  0.824349                 0.214552
# 7                  0.687635                 0.165480
# 8                  0.197225                 0.076571
# 9                  0.602581                 0.181765
# 10                 0.277439                 0.100806
# 11                 0.444959                 0.116879
# 12                 1.070000                 0.329703
# 13                 1.340000                 0.444220
# 14                 0.746578                 0.204679
# 15                 0.200000                 0.098520
# 16                 0.490000                 0.216889
# 17                 0.197225                 0.065806
# 18                 0.826226                 0.413113
# 19                 0.305501                 0.136823
# 20                 0.572734                 0.156299
# 21                 0.305501                 0.119125
# 22                 0.701727                 0.289372
# 23                 0.359983                 0.086092
# 24                 0.639849                 0.185151
# 25                 0.200688                 0.052468
# 26                 0.320000                 0.140373
# 27                 0.374009                 0.102771
# 28                 0.478081                 0.125960
# 29                 0.305501                 0.120524
# 32                 1.070000                 0.535000
# ...                     ...                      ...
# 2306               0.687635                 0.173785
# 2307               0.356331                 0.149983
# 2308               0.503787                 0.176680
# 2309               0.687635                 0.164651
# 2310               0.244033                 0.065713
# 2311               1.001973                 0.297869
# 2312               0.186823                 0.068224
# 2313               0.467915                 0.123125
# 2314               0.569081                 0.193909
# 2315               1.171973                 0.296299
# 2316               0.217589                 0.068982
# 2317               0.563787                 0.168682
# 2318               0.664885                 0.176063
# 2319               0.118795                 0.046060
# 2320               0.246244                 0.080079
# 2322               0.503787                 0.178676
# 2323               0.872134                 0.277056
# 2325               0.236784                 0.086636
# 2326               1.174277                 0.331144
# 2327               0.320000                 0.132509
# 2328               0.877429                 0.278848
# 2329               0.569081                 0.169658
# 2330               1.030000                 0.504595
# 2331               0.470258                 0.158488
# 2332               0.830341                 0.406782
# 2333               1.032791                 0.505962
# 2334               0.464600                 0.134279
# 2335               0.550000                 0.269444
# 2336               0.563787                 0.190696
# 2337               1.177267                 0.331668
#
# [2048 rows x 127 columns]

# %%
#Band gap data
delta_e = np.array(training_set_use["delta_e"], dtype=float)
print delta_e

#Energy range data
delta_e = np.array(training_set_use["delta_e"], dtype=float)

energy_range = np.zeros(np.shape(delta_e), dtype=str)
for i in range(len(delta_e)):
    if delta_e[i] < 0:
        energy_range[i] = "neg"
    else:
        energy_range[i] = "pos"
        
print energy_range
# Out:
# [-1.55573181 -0.53416896 -1.06850412 ...,  0.46489684 -4.07700786 -2.733333  ]
# ['n' 'n' 'n' ..., 'p' 'n' 'n']

# %% [markdown]
# ### Predict formation energy range using classifiers

# %%
#Classifier step
model1 = RandomForestClassifier(n_estimators=10, criterion="gini", min_samples_split=2)
model1.fit(training_set_use[attr_names], energy_range)
prediction = model1.predict(training_set_use[attr_names])

# %%
pd.crosstab(energy_range, prediction, rownames=["actual"], colnames=["predicted"])
# Out:
# predicted     n   p
# actual
# n          2035   0
# p             0  13

# %%
#Classifier step
model2 = DecisionTreeClassifier()
model2.fit(training_set_use[attr_names], energy_range)
prediction = model2.predict(training_set_use[attr_names])

# %%
pd.crosstab(energy_range, prediction, rownames=["actual"], colnames=["predicted"])
# Out:
# predicted     n   p
# actual
# n          2035   0
# p             0  13

# %%
rf_model = RandomForestRegressor()
rf_model.fit(training_set_use[attr_names], delta_e)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_split=1e-07, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=10, n_jobs=1, oob_score=False, random_state=None,
#            verbose=0, warm_start=False)

# %%
prediction = rf_model.predict(training_set_use[attr_names])

# %%
plt.scatter(delta_e, prediction)
plt.plot(range(-5,2), range(-5,2), 'r')
plt.xlabel("OQMD Data")
plt.ylabel("Predicted")

# %%
# %%time

errors = cross_val_score(RandomForestRegressor(), training_set_use[attr_names], delta_e, scoring="neg_mean_absolute_error", cv=10)
mae = np.mean(np.abs(errors))

print mae
# Out:
# 0.114868731555
# CPU times: user 6.37 s, sys: 7.86 ms, total: 6.38 s
# Wall time: 6.38 s

# %% [markdown]
# ### Decision Tree Regressor

# %%
dt_model = DecisionTreeRegressor()
dt_model.fit(training_set_use[attr_names], delta_e)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#            max_leaf_nodes=None, min_impurity_split=1e-07,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#            splitter='best')

# %%
dt_prediction = dt_model.predict(training_set_use[attr_names])

# %%
plt.scatter(delta_e, dt_prediction)
plt.plot(range(-5,2), range(-5,2), 'r')
plt.xlabel("OQMD Data")
plt.ylabel("Predicted")

# %%
# %%time

errors = cross_val_score(DecisionTreeRegressor(), training_set_use[attr_names], delta_e, scoring="neg_mean_absolute_error", cv=10)
mae = np.mean(np.abs(errors))

print mae
# Out:
# 0.15956929382
# CPU times: user 1.04 s, sys: 2.28 ms, total: 1.04 s
# Wall time: 1.04 s
