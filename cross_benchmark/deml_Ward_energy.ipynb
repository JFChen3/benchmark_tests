# %% [markdown]
# # Formation Energy Prediction using *Ward 2016* Method
#
# This notebook uses the method from [Ward 2016](https://www.nature.com/articles/npjcompumats201628) to predict formation energy of compounds. Specifically, it uses the set of composition based attributes described in the paper to train a machine learning model.

# %%
training_file = 'datasets/deml_dataset.csv'
delimiter = ','
comp_col = 'composition'

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import matminer

from pymatgen import Composition
from matminer.featurizers import composition as cp
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor
from sklearn.model_selection import cross_val_score, KFold

# %matplotlib inline

# %% [markdown]
# ## Load input files and generate descriptors
# The training set is a set of ~300000 compounds with data extracted from the Open Quantum Materials Database (OQMD)

# %%
def load_training_set(files, sep):
    """Function to read data files and load them into a Pandas DataFrame"""
        
    if type(files) is not list:
        training_set = pd.read_csv(files, sep=sep)
    else:
        training_set = pd.DataFrame()
        for i in range(len(files)):
            training_set.append(pd.read_csv(files[i], sep=sep[i]))

    return training_set

training_set = load_training_set(training_file, delimiter)

# %% [markdown]
# ## Create PyMatGen Composition objects

# %%
comp_objects = [Composition(comp) for comp in training_set[comp_col]]
comp_objects
training_set = training_set.assign(comp_obj=comp_objects)

training_set
# Out:
#              composition   delta_e                 comp_obj
# 0                  As1Y1 -1.555732                  (As, Y)
# 1                  Ga1P1 -0.534169                  (Ga, P)
# 2               Ga2Mg1S4 -1.068504              (S, Mg, Ga)
# 3             Cd4K1O12V3 -1.968765            (O, Cd, K, V)
# 4     Al1Ca1Fe1Na1O12Si4 -2.949067  (O, Na, Al, Si, Ca, Fe)
# 5               Hf1O3Pb1 -2.830320              (Hf, O, Pb)
# 6        Al2Ba2Co1F14Mn1 -3.488390      (Ba, F, Co, Al, Mn)
# 7        Ba2Cd1F14Fe2Mn1 -3.007836      (Ba, F, Fe, Cd, Mn)
# 8               Be2O4Si1 -3.020793              (O, Be, Si)
# 9        Ba2Ca1Cu1F14Ga2 -3.325601      (Ba, F, Ca, Cu, Ga)
# 10              Ge1O4Zn2 -1.809053              (Ge, O, Zn)
# 11           Ca1Cr1F7Sr1 -3.707430          (Cr, F, Ca, Sr)
# 12             As3Ga1Na6 -0.523152             (As, Na, Ga)
# 13              Ga1Na6P3 -0.548523              (P, Na, Ga)
# 14       Al2Ba2Cu1F14Mn1 -3.463375      (Ba, Mn, Cu, Al, F)
# 15              O4Si1Zn2 -2.286625              (O, Zn, Si)
# 16              Al2Ca1O4 -3.293900              (O, Ca, Al)
# 17           K3Nb3O13Si2 -2.818445           (O, Nb, K, Si)
# 18                Ga1Sb1 -0.167088                 (Sb, Ga)
# 19              Ba1O4Sc2 -3.534127              (Ba, O, Sc)
# 20          Ge3Na4O12Zr2 -2.477888          (Ge, Zr, Na, O)
# 21          Ba3In2O11Zn5 -2.038818          (Ba, O, Zn, In)
# 22             Ba1Mn1Sb2 -0.452687             (Ba, Mn, Sb)
# 23              Ge4O9Sr1 -2.158955              (Ge, O, Sr)
# 24           Ba1Co1O4Si1 -2.518078          (Ba, O, Co, Si)
# 25           Ge2K3Nb3O13 -2.469440           (O, Ge, K, Nb)
# 26           Ba1Mg1O4Si1 -3.156372          (Ba, O, Mg, Si)
# 27          Na2O13Si4Ti2 -2.994975          (O, Na, Ti, Si)
# 28             Ba2Cu5F14 -2.422743              (Ba, F, Cu)
# 29           Ba1O4Si1Zn1 -2.780893          (Ba, O, Si, Zn)
# ...                  ...       ...                      ...
# 2308         Ba1Ca1F7Ga1 -3.705833          (Ba, F, Ca, Ga)
# 2309         Ba1F7Fe1Mn1 -3.028555          (Ba, Mn, Fe, F)
# 2310          In1K3Na2O4 -1.555390           (K, O, Na, In)
# 2311         Mg4Na1O12V3 -2.663958           (O, Na, Mg, V)
# 2312            Be1Na2O2 -2.117752              (O, Na, Be)
# 2313         Ba1Ca1Cr1F7 -3.708148          (Cr, Ba, Ca, F)
# 2314         Ba1F7Na1Zr1 -3.894199          (Ba, Zr, Na, F)
# 2315          Al1Mo1O7V1 -2.527260           (O, Mo, Al, V)
# 2316             Cu1F3K1 -2.326135               (F, K, Cu)
# 2317            Al1Ca2F7 -4.070533              (F, Ca, Al)
# 2318          Cu1F7Hf1K1 -3.213797           (Hf, F, K, Cu)
# 2319             F3K1Sn1 -2.769554               (F, Sn, K)
# 2320            Cl6In1K3 -1.878524              (In, K, Cl)
# 2321            O3Pb1Zr1 -2.688863              (Zr, O, Pb)
# 2322         Ba1Cd1F7Ga1 -3.177542          (Ba, F, Cd, Ga)
# 2323            Al1Fe1O3 -2.451067              (O, Fe, Al)
# 2324            Cr1F7Pb2 -2.763725              (Cr, F, Pb)
# 2325        Ca1Cu3O12Ti4 -2.555322          (O, Ca, Cu, Ti)
# 2326             Hf1O7V2 -2.804765               (Hf, O, V)
# 2327            Mg1O3Si1 -3.074223              (O, Mg, Si)
# 2328            Fe1O3Zr1 -2.695420              (Zr, O, Fe)
# 2329          F7K1Sn1Zr1 -3.405506           (Zr, F, Sn, K)
# 2330               Cd3P2 -0.158201                  (Cd, P)
# 2331            Ag1Nb1O3 -2.019452              (O, Nb, Ag)
# 2332              Al2Te3 -0.450581                 (Te, Al)
# 2333               Be3P2 -0.332600                  (Be, P)
# 2334            Mo1Na4O5 -2.109603              (O, Mo, Na)
# 2335               Cd3N2  0.464897                  (Cd, N)
# 2336         Al1Ba1Ca1F7 -4.077008          (Ba, F, Ca, Al)
# 2337             O7V2Zr1 -2.733333               (Zr, O, V)
#
# [2338 rows x 3 columns]

# %% [markdown]
# ## Compute descriptors using MatMiner
# Here, we compute 145 composition based attributes as described in *Ward 2016* using the [MatMiner](https://github.com/hackingmaterials/matminer) implementation of the featurizer.

# %%
# %%time

def calc_attributes(training_set):
    not_attr = list(training_set) #Non-attribute columns
    training_set_updated = cp.Stoichiometry().featurize_dataframe(training_set, col_id="comp_obj")
    training_set_updated = cp.ElementProperty().featurize_dataframe(training_set_updated, col_id="comp_obj")
    training_set_updated = cp.ValenceOrbital().featurize_dataframe(training_set_updated, col_id="comp_obj")
    training_set_updated = cp.IonProperty().featurize_dataframe(training_set_updated, col_id="comp_obj")
    all_cols = list(training_set_updated)
    attr_names = [col for col in all_cols if col not in not_attr]
    return training_set_updated, attr_names

#%lprun -f calc_attributes calc_attributes()

all_descriptors, attr_names = calc_attributes(training_set)
print np.shape(all_descriptors)
# Out:
# (2338, 152)
# CPU times: user 7.48 s, sys: 29.3 ms, total: 7.51 s
# Wall time: 7.5 s

# %% [markdown]
# ## Predicting formation energy

# %%
#Drop NaN values from training set

training_set_use = all_descriptors.replace("None", np.nan)
training_set_use = training_set_use.replace(np.inf, np.nan)
training_set_use = training_set_use.dropna()

training_set_use
# Out:
#              composition   delta_e                 comp_obj  0-norm   10-norm  \
# 0                  As1Y1 -1.555732                  (As, Y)     2.0  0.535887
# 1                  Ga1P1 -0.534169                  (Ga, P)     2.0  0.535887
# 2               Ga2Mg1S4 -1.068504              (S, Mg, Ga)     3.0  0.571484
# 3             Cd4K1O12V3 -1.968765            (O, Cd, K, V)     4.0  0.600001
# 4     Al1Ca1Fe1Na1O12Si4 -2.949067  (O, Na, Al, Si, Ca, Fe)     6.0  0.600001
# 5               Hf1O3Pb1 -2.830320              (Hf, O, Pb)     3.0  0.600002
# 6        Al2Ba2Co1F14Mn1 -3.488390      (Ba, F, Co, Al, Mn)     5.0  0.700000
# 7        Ba2Cd1F14Fe2Mn1 -3.007836      (Ba, F, Fe, Cd, Mn)     5.0  0.700000
# 8               Be2O4Si1 -3.020793              (O, Be, Si)     3.0  0.571484
# 9        Ba2Ca1Cu1F14Ga2 -3.325601      (Ba, F, Ca, Cu, Ga)     5.0  0.700000
# 10              Ge1O4Zn2 -1.809053              (Ge, O, Zn)     3.0  0.571484
# 11           Ca1Cr1F7Sr1 -3.707430          (Cr, F, Ca, Sr)     4.0  0.700000
# 12             As3Ga1Na6 -0.523152             (As, Na, Ga)     3.0  0.600059
# 13              Ga1Na6P3 -0.548523              (P, Na, Ga)     3.0  0.600059
# 14       Al2Ba2Cu1F14Mn1 -3.463375      (Ba, Mn, Cu, Al, F)     5.0  0.700000
# 15              O4Si1Zn2 -2.286625              (O, Zn, Si)     3.0  0.571484
# 16              Al2Ca1O4 -3.293900              (O, Ca, Al)     3.0  0.571484
# 17           K3Nb3O13Si2 -2.818445           (O, Nb, K, Si)     4.0  0.619048
# 18                Ga1Sb1 -0.167088                 (Sb, Ga)     2.0  0.535887
# 19              Ba1O4Sc2 -3.534127              (Ba, O, Sc)     3.0  0.571484
# 20          Ge3Na4O12Zr2 -2.477888          (Ge, Zr, Na, O)     4.0  0.571430
# 21          Ba3In2O11Zn5 -2.038818          (Ba, O, Zn, In)     4.0  0.523829
# 22             Ba1Mn1Sb2 -0.452687             (Ba, Mn, Sb)     3.0  0.500098
# 23              Ge4O9Sr1 -2.158955              (Ge, O, Sr)     3.0  0.642876
# 24           Ba1Co1O4Si1 -2.518078          (Ba, O, Co, Si)     4.0  0.571429
# 25           Ge2K3Nb3O13 -2.469440           (O, Ge, K, Nb)     4.0  0.619048
# 26           Ba1Mg1O4Si1 -3.156372          (Ba, O, Mg, Si)     4.0  0.571429
# 27          Na2O13Si4Ti2 -2.994975          (O, Na, Ti, Si)     4.0  0.619048
# 2332  0.721110  0.654213  0.615030  0.604895             48.296861
# 2333  0.721110  0.654213  0.615030  0.604895             10.541558
# 2334  0.648074  0.574890  0.529188  0.513786             13.833678
# 2335  0.721110  0.654213  0.615030  0.604895             47.234064
# 2336  0.721110  0.702035  0.700025  0.700000             21.985986
# 2337  0.734847  0.706070  0.700275  0.700016             20.315232
#
#             ...          avg f valence electrons  avg p valence electrons  \
# 0           ...                              0.0                 1.500000
# 1           ...                              0.0                 2.000000
# 2           ...                              0.0                 2.571429
# 3           ...                              0.0                 2.400000
# 4           ...                              0.0                 2.850000
# 5           ...                              5.6                 2.800000
# 6           ...                              0.0                 3.600000
# 7           ...                              0.0                 3.500000
# 8           ...                              0.0                 2.571429
# 9           ...                              0.0                 3.600000
# 10          ...                              0.0                 2.571429
# 11          ...                              0.0                 3.500000
# 12          ...                              0.0                 1.000000
# 13          ...                              0.0                 1.000000
# 14          ...                              0.0                 3.600000
# 15          ...                              0.0                 2.571429
# 16          ...                              0.0                 2.571429
# 17          ...                              0.0                 2.666667
# 18          ...                              0.0                 2.000000
# 19          ...                              0.0                 2.285714
# 20          ...                              0.0                 2.571429
# 21          ...                              0.0                 2.190476
# 22          ...                              0.0                 1.500000
# 23          ...                              0.0                 3.142857
# 24          ...                              0.0                 2.571429
# 25          ...                              0.0                 2.666667
# 26          ...                              0.0                 2.571429
# 27          ...                              0.0                 2.857143
# 28          ...                              0.0                 3.333333
# 29          ...                              0.0                 2.571429
# ...         ...                              ...                      ...
# 2308        ...                              0.0                 3.600000
# 2309        ...                              0.0                 3.500000
# 2310        ...                              0.0                 1.700000
# 2311        ...                              0.0                 2.400000
# 2312        ...                              0.0                 1.600000
# 2313        ...                              0.0                 3.500000
# 2314        ...                              0.0                 3.500000
# 2315        ...                              0.0                 2.900000
# 2316        ...                              0.0                 3.000000
# 2317        ...                              0.0                 3.600000
# 2318        ...                              1.4                 3.500000
# 2319        ...                              0.0                 3.400000
# 2320        ...                              0.0                 3.100000
# 2321        ...                              2.8                 2.800000
# 2322        ...                              0.0                 3.600000
# 2323        ...                              0.0                 2.600000
# 2324        ...                              2.8                 3.900000
# 2325        ...                              0.0                 2.400000
# 2326        ...                              1.4                 2.800000
# 2327        ...                              0.0                 2.800000
# 2328        ...                              0.0                 2.400000
# 2329        ...                              0.0                 3.700000
# 2330        ...                              0.0                 1.200000
# 2331        ...                              0.0                 2.400000
# 2332        ...                              0.0                 2.800000
# 2333        ...                              0.0                 1.200000
# 2334        ...                              0.0                 2.000000
# 2335        ...                              0.0                 1.200000
# 2336        ...                              0.0                 3.600000
# 2337        ...                              0.0                 2.800000
#
#       avg s valence electrons  frac d valence electrons  \
# 0                    2.000000                  0.611111
# 1                    2.000000                  0.555556
# 2                    2.000000                  0.384615
# 3                    1.950000                  0.360294
# 4                    1.950000                  0.058824
# 5                    2.000000                  0.187500
# 6                    2.000000                  0.096774
# 7                    2.000000                  0.197080
# 8                    2.000000                  0.000000
0
# 2                   1.0
# 3                   1.0
# 4                   1.0
# 5                   1.0
# 6                   1.0
# 7                   1.0
# 8                   1.0
# 9                   1.0
# 10                  1.0
# 11                  1.0
# 12                  1.0
# 13                  1.0
# 14                  1.0
# 15                  1.0
# 16                  1.0
# 17                  1.0
# 18                  1.0
# 19                  1.0
# 20                  1.0
# 21                  1.0
# 22                  1.0
# 23                  1.0
# 24                  1.0
# 25                  1.0
# 26                  1.0
# 27                  1.0
# 28                  1.0
# 29                  1.0
# ...                 ...
# 2308                1.0
# 2309                1.0
# 2310                1.0
# 2311                1.0
# 2312                1.0
# 2313                1.0
# 2314                1.0
# 2315                1.0
# 2316                1.0
# 2317                1.0
# 2318                1.0
# 2319                1.0
# 2320                1.0
# 2321                1.0
# 2322                1.0
# 2323                1.0
# 2324                1.0
# 2325                1.0
# 2326                1.0
# 2327                1.0
# 2328                1.0
# 2329                1.0
# 2330                1.0
# 2331                1.0
# 2332                1.0
# 2333                1.0
# 2334                1.0
# 2335                1.0
# 2336                1.0
# 2337                1.0
#
# [2338 rows x 152 columns]

# %%
#Discretize into positive/negative formation energy

delta_e = np.array(training_set_use["delta_e"], dtype=float)

energy_range = np.zeros(np.shape(delta_e), dtype=str)
for i in range(len(delta_e)):
    if delta_e[i] < 0:
        energy_range[i] = "neg"
    else:
        energy_range[i] = "pos"
        
print energy_range
# Out:
# ['n' 'n' 'n' ..., 'p' 'n' 'n']

# %%
#Random Forest Classifier

model1 = RandomForestClassifier(n_estimators=8, criterion="gini", min_samples_split=2)
model1.fit(training_set_use[attr_names], energy_range)
prediction = model1.predict(training_set_use[attr_names])

# %%
pd.crosstab(energy_range, prediction, rownames=["actual"], colnames=["predicted"])
# Out:
# predicted     n   p
# actual
# n          2322   1
# p             2  13

# %%
#Decision Trees Classifier

model2 = DecisionTreeClassifier()
model2.fit(training_set_use[attr_names], energy_range)
prediction = model2.predict(training_set_use[attr_names])

# %%
pd.crosstab(energy_range, prediction, rownames=["actual"], colnames=["predicted"])
# Out:
# predicted     n   p
# actual
# n          2323   0
# p             0  15

# %%
rf_model = RandomForestRegressor()
rf_model.fit(training_set_use[attr_names], delta_e)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_split=1e-07, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=10, n_jobs=1, oob_score=False, random_state=None,
#            verbose=0, warm_start=False)

# %%
prediction = rf_model.predict(training_set_use[attr_names])

# %%
plt.scatter(delta_e, prediction)
plt.plot(range(-5,8), range(-5,8), 'r')
plt.xlabel("OQMD Data")
plt.ylabel("Predicted")

# %%
# %%time

errors = cross_val_score(RandomForestRegressor(), training_set_use[attr_names], delta_e, scoring="neg_mean_absolute_error", cv=10)
mae = np.mean(np.abs(errors))

print mae
# Out:
# 0.123050741438
# CPU times: user 6.48 s, sys: 7.66 ms, total: 6.49 s
# Wall time: 6.49 s

# %% [markdown]
# ### Decision Tree

# %%
dt_model = DecisionTreeRegressor()
dt_model.fit(training_set_use[attr_names], delta_e)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#            max_leaf_nodes=None, min_impurity_split=1e-07,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#            splitter='best')

# %%
prediction = dt_model.predict(training_set_use[attr_names])

# %%
plt.scatter(delta_e, prediction)
plt.plot(range(-5,8), range(-5,8), 'r')
plt.xlabel("OQMD Data")
plt.ylabel("Predicted")

# %%
# %%time

errors = cross_val_score(DecisionTreeRegressor(), training_set_use[attr_names], delta_e, scoring="neg_mean_absolute_error", cv=10)
mae = np.mean(np.abs(errors))

print mae
# Out:
# 0.169746076351
# CPU times: user 1.04 s, sys: 3.32 ms, total: 1.05 s
# Wall time: 1.05 s
