# %% [markdown]
# # Band Gap Prediction using *Ward 2016* Method
#
# This notebook uses the method from [Ward 2016](https://www.nature.com/articles/npjcompumats201628) to predict band gap of compounds. Specifically, it uses the set of composition based attributes described in the paper to train a machine learning model.

# %%
training_file = "datasets/oqmd_groundstate.data"
delimiter = ' '
comp_col = "comp"

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import matminer

from pymatgen import Composition
from matminer.featurizers import composition as cp
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor
from sklearn.model_selection import cross_val_score, KFold

# %matplotlib inline

# %% [markdown]
# ## Load input files and generate descriptors
# The training set is a set of ~300000 compounds with data extracted from the Open Quantum Materials Database (OQMD)

# %%
def load_training_set(files, sep):
    """Function to read data files and load them into a Pandas DataFrame"""
        
    if type(files) is not list:
        training_set = pd.read_csv(files, sep=sep)
    else:
        training_set = pd.DataFrame()
        for i in range(len(files)):
            training_set.append(pd.read_csv(files[i], sep=sep[i]))

    return training_set

training_set = load_training_set(training_file, delimiter)
# Out:
# /Users/jimingchen/anaconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2821: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   if self.run_code(code, result):

# %%
training_set = training_set.replace("None", np.nan)
training_set = training_set.dropna()

# %% [markdown]
# ## Create PyMatGen Composition objects

# %%
comp_objects = [Composition(comp) for comp in training_set[comp_col]]
comp_objects
training_set = training_set.assign(comp_obj=comp_objects)

training_set
# Out:
#                comp  energy_pa  volume_pa           magmom_pa bandgap  \
# 1               Hf1  -9.923202   22.36760  -6.75333333333e-05     0.0
# 3               Mo1 -10.419117   15.92040   -0.00447616666667     0.0
# 4               Nb1  -9.800921   18.67330    0.00419203333333     0.0
# 5               Ni1  -5.552162   10.70220      0.611777266667     0.0
# 6               Os1 -11.181135   14.28270            7.71e-05     0.0
# 8               Pm1  -4.741485   34.23060     0.0191255333333     0.0
# 9               Pr1  -4.768796   35.98410   -0.00777663333333     0.0
# 11              Sm1  -4.711020   33.58290     0.0106331333333     0.0
# 13              Tc1 -10.345199   14.47630   -0.00934373333333     0.0
# 17              Ac1  -4.102718   44.87960           0.0010475     0.0
# 18               V1  -8.940979   13.16860           0.0023132     0.0
# 21              Rh1  -7.269405   13.98550          -0.0141667     0.0
# 22              Ir1  -8.854920   14.46520           0.0032348     0.0
# 23              Pt1  -6.055760   15.54030            0.021855     0.0
# 24           Sm1Zn1  -3.317846   23.93560          0.01579015     0.0
# 25           Au1Mn1  -6.160574   16.58480           2.0554978     0.0
# 26              Eu1  -1.887573   40.37090          -0.0003424     0.0
# 28           Pr1Zn1  -3.331509   25.31450          0.00710795     0.0
# 29              Tm1  -4.473978   29.74610          0.01469015     0.0
# 32           Rh1Ti1  -8.251520   14.81490          0.00888405     0.0
# 34              Fe1  -8.307898   11.19140            2.182114     0.0
# 35            Fe1V1  -8.748676   11.78440          0.40052985     0.0
# 36           Ru1Yb1  -5.054588   18.54860            0.189519     0.0
# 37           Nb1Rh1  -9.092180   15.87320          -0.0007552     0.0
# 40           Hg1Ti1  -4.035695   18.60230            0.452018     0.0
# 41           Tb1Zn1  -3.289283   22.92810          0.07912045     0.0
# 43           Fe1Pd1  -6.808098   13.76310          1.63304835     0.0
# 44           Sb1Tb1  -5.524906   30.06420           0.0001865     0.0
# 26      0.000000                0.0           True             (Eu)
# 28     -0.311093   -0.0887676651384           True         (Pr, Zn)
# 29      0.001046        0.001046365           True             (Tm)
# 32     -0.746765   0.00147898010987           True         (Rh, Ti)
# 34      0.000000                0.0           True             (Fe)
# 35     -0.124238       0.0151847775           True          (Fe, V)
# 36      0.302794        0.302793785           True         (Ru, Yb)
# 37     -0.410521    -0.016468616875           True         (Nb, Rh)
# 40      0.031803     0.100948264755           True         (Hg, Ti)
# 41     -0.012391     0.118283217431           True         (Tb, Zn)
# 43     -0.065790   0.00611422202619           True         (Fe, Pd)
# 44     -0.822247    -0.224976821428           True         (Tb, Sb)
# 45     -0.243948  5.68000000101e-06           True          (Cu, Y)
# 46     -1.116636    -0.227895693073           True         (Ho, Sb)
# ...          ...                ...            ...              ...
# 228636 -1.964164     0.278830321764           True      (O, Li, Eu)
# 228637 -2.388619     0.816263253052           True       (O, U, Pt)
# 228638 -2.492030     0.486191437837           True      (O, Pa, Np)
# 228639 -2.904240       0.2451766587           True      (O, Ho, Cs)
# 228640 -3.053769   -0.0463371761088           True  (Cr, Nb, Ca, O)
# 228641 -3.587463     0.206756591657           True      (O, Er, Lu)
# 228642 -1.862873      1.12358449695           True      (O, Pu, Si)
# 228643 -2.216497     0.114586034523           True      (O, Np, Rb)
# 228644 -2.103899      1.10098314805           True       (O, U, Ir)
# 228645 -1.601784     0.594789118037           True       (O, Ho, K)
# 228646 -1.209255    0.0901198824356           True      (O, Ir, Rb)
# 228647 -2.254928      0.52070395718           True      (O, Pa, Ag)
# 228648 -3.337922     0.150003590477           True      (O, Pr, Pu)
# 228649 -1.449136     0.805894778766           True      (O, Re, Pu)
# 228650 -1.114274     0.834230410659           True      (O, Np, Pt)
# 228651 -0.892992     0.238302000343           True      (O, Li, Rh)
# 228652 -0.780835     0.154183585227           True      (O, Li, Pt)
# 228653 -1.084938    0.0738786815651           True      (O, Li, Ir)
# 228655 -1.473970    0.0334335448082           True      (O, Li, Rh)
# 228656 -1.360111    0.0359201393534           True      (O, Li, Pt)
# 228657 -2.877865     0.147293132775           True      (Hf, O, Li)
# 228658 -1.617889    0.0320992857716           True      (O, Li, Ru)
# 228659 -2.373185     0.128672916976           True       (O, Li, V)
# 228660 -1.212716     0.185356295002           True      (O, Li, Ni)
# 228661 -1.466693     0.021027005819           True      (O, Li, Co)
# 228662 -1.667657    0.0824166156411           True      (O, Fe, Li)
# 228663 -2.053849     0.149710667152           True      (Cr, O, Li)
# 228664 -1.489695    0.0295860787368           True      (O, Li, Ir)
# 228665 -2.661792     0.125867030468           True      (O, Li, Ti)
# 228666 -1.615269     0.125693107873           True      (O, Li, Tc)
#
# [117454 rows x 9 columns]

# %% [markdown]
# ## Compute descriptors using MatMiner
# Here, we compute 145 composition based attributes as described in *Ward 2016* using the [MatMiner](https://github.com/hackingmaterials/matminer) implementation of the featurizer.

# %%
# %%time

def calc_attributes(training_set):
    not_attr = list(training_set) #Non-attribute columns
    training_set_updated = cp.Stoichiometry().featurize_dataframe(training_set, col_id="comp_obj")
    training_set_updated = cp.ElementProperty().featurize_dataframe(training_set_updated, col_id="comp_obj")
    training_set_updated = cp.ValenceOrbital().featurize_dataframe(training_set_updated, col_id="comp_obj")
    training_set_updated = cp.IonProperty().featurize_dataframe(training_set_updated, col_id="comp_obj")
    all_cols = list(training_set_updated)
    attr_names = [col for col in all_cols if col not in not_attr]
    return training_set_updated, attr_names

#%lprun -f calc_attributes calc_attributes()

all_descriptors, attr_names = calc_attributes(training_set)
print np.shape(all_descriptors)
# Out:
# (117454, 158)
# CPU times: user 6min 3s, sys: 1.69 s, total: 6min 5s
# Wall time: 6min 5s

# %% [markdown]
# ## Predicting band gaps

# %%
#Drop NaN values from training set

training_set_use = all_descriptors.replace("None", np.nan)
training_set_use = training_set_use.replace(np.inf, np.nan)
training_set_use = training_set_use.dropna()

training_set_use
# Out:
#                comp  energy_pa  volume_pa           magmom_pa bandgap  \
# 1               Hf1  -9.923202   22.36760  -6.75333333333e-05     0.0
# 3               Mo1 -10.419117   15.92040   -0.00447616666667     0.0
# 4               Nb1  -9.800921   18.67330    0.00419203333333     0.0
# 5               Ni1  -5.552162   10.70220      0.611777266667     0.0
# 6               Os1 -11.181135   14.28270            7.71e-05     0.0
# 8               Pm1  -4.741485   34.23060     0.0191255333333     0.0
# 9               Pr1  -4.768796   35.98410   -0.00777663333333     0.0
# 11              Sm1  -4.711020   33.58290     0.0106331333333     0.0
# 13              Tc1 -10.345199   14.47630   -0.00934373333333     0.0
# 17              Ac1  -4.102718   44.87960           0.0010475     0.0
# 18               V1  -8.940979   13.16860           0.0023132     0.0
# 21              Rh1  -7.269405   13.98550          -0.0141667     0.0
# 22              Ir1  -8.854920   14.46520           0.0032348     0.0
# 23              Pt1  -6.055760   15.54030            0.021855     0.0
# 24           Sm1Zn1  -3.317846   23.93560          0.01579015     0.0
# 25           Au1Mn1  -6.160574   16.58480           2.0554978     0.0
# 26              Eu1  -1.887573   40.37090          -0.0003424     0.0
# 28           Pr1Zn1  -3.331509   25.31450          0.00710795     0.0
# 29              Tm1  -4.473978   29.74610          0.01469015     0.0
# 32           Rh1Ti1  -8.251520   14.81490          0.00888405     0.0
# 34              Fe1  -8.307898   11.19140            2.182114     0.0
# 35            Fe1V1  -8.748676   11.78440          0.40052985     0.0
# 36           Ru1Yb1  -5.054588   18.54860            0.189519     0.0
# 37           Nb1Rh1  -9.092180   15.87320          -0.0007552     0.0
# 40           Hg1Ti1  -4.035695   18.60230            0.452018     0.0
# 41           Tb1Zn1  -3.289283   22.92810          0.07912045     0.0
# 43           Fe1Pd1  -6.808098   13.76310          1.63304835     0.0
# 44           Sb1Tb1  -5.524906   30.06420           0.0001865     0.0
# 45            Cu1Y1  -5.334138   20.79830          -0.0017787     0.0
# 46           Ho1Sb1  -5.463814   29.32800           0.0001791     0.0
# ...             ...        ...        ...                 ...     ...
# 228636     Eu1Li2O3  -5.148707   10.79240      0.333177966667       0
# 228637      O4Pt1U2  -8.307793   17.94130      0.559426657143       0
# 228638     Np1O4Pa2  -9.227994   17.63860          0.85032325       0
# 34      0.000000                0.0           True             (Fe)     1.0
# 35     -0.124238       0.0151847775           True          (Fe, V)     2.0
# 36      0.302794        0.302793785           True         (Ru, Yb)     2.0
# 37     -0.410521    -0.016468616875           True         (Nb, Rh)     2.0
# 40      0.031803     0.100948264755           True         (Hg, Ti)     2.0
# 41     -0.012391     0.118283217431           True         (Tb, Zn)     2.0
# 43     -0.065790   0.00611422202619           True         (Fe, Pd)     2.0
# 44     -0.822247    -0.224976821428           True         (Tb, Sb)     2.0
# 45     -0.243948  5.68000000101e-06           True          (Cu, Y)     2.0
# 46     -1.116636    -0.227895693073           True         (Ho, Sb)     2.0
# ...          ...                ...            ...              ...     ...
# 228636 -1.964164     0.278830321764           True      (O, Li, Eu)     3.0
# 228637 -2.388619     0.816263253052           True       (O, U, Pt)     3.0
# 228638 -2.492030     0.486191437837           True      (O, Pa, Np)     3.0
# 228639 -2.904240       0.2451766587           True      (O, Ho, Cs)     3.0
# 228640 -3.053769   -0.0463371761088           True  (Cr, Nb, Ca, O)     4.0
# 228641 -3.587463     0.206756591657           True      (O, Er, Lu)     3.0
# 228642 -1.862873      1.12358449695           True      (O, Pu, Si)     3.0
# 228643 -2.216497     0.114586034523           True      (O, Np, Rb)     3.0
# 228644 -2.103899      1.10098314805           True       (O, U, Ir)     3.0
# 228645 -1.601784     0.594789118037           True       (O, Ho, K)     3.0
# 228646 -1.209255    0.0901198824356           True      (O, Ir, Rb)     3.0
# 228647 -2.254928      0.52070395718           True      (O, Pa, Ag)     3.0
# 228648 -3.337922     0.150003590477           True      (O, Pr, Pu)     3.0
# 228649 -1.449136     0.805894778766           True      (O, Re, Pu)     3.0
# 228650 -1.114274     0.834230410659           True      (O, Np, Pt)     3.0
# 228651 -0.892992     0.238302000343           True      (O, Li, Rh)     3.0
# 228652 -0.780835     0.154183585227           True      (O, Li, Pt)     3.0
# 228653 -1.084938    0.0738786815651           True      (O, Li, Ir)     3.0
# 228655 -1.473970    0.0334335448082           True      (O, Li, Rh)     3.0
# 228656 -1.360111    0.0359201393534           True      (O, Li, Pt)     3.0
# 228657 -2.877865     0.147293132775           True      (Hf, O, Li)     3.0
# 228658 -1.617889    0.0320992857716           True      (O, Li, Ru)     3.0
# 228659 -2.373185     0.128672916976           True       (O, Li, V)     3.0
# 228660 -1.212716     0.185356295002           True      (O, Li, Ni)     3.0
# 228661 -1.466693     0.021027005819           True      (O, Li, Co)     3.0
# 228662 -1.667657    0.0824166156411           True      (O, Fe, Li)     3.0
# 228663 -2.053849     0.149710667152           True      (Cr, O, Li)     3.0
# 228664 -1.489695    0.0295860787368           True      (O, Li, Ir)     3.0
# 228665 -2.661792     0.125867030468           True      (O, Li, Ti)     3.0
# 228666 -1.615269     0.125693107873           True      (O, Li, Tc)     3.0
#
#               ...          avg f valence electrons  avg p valence electrons  \
# 1             ...                        14.000000                 0.000000
# 3             ...                         0.000000                 0.000000
# 4             ...                         0.000000                 0.000000
# 5             ...                         0.000000                 0.000000
# 6             ...                        14.000000                 0.000000
# 8             ...                         5.000000                 0.000000
# 9             ...                         3.000000                 0.000000
# 11            ...                         6.000000                 0.000000
# 13            ...                         0.000000                 0.000000
# 17            ...                         0.000000                 0.000000
# 18            ...                         0.000000                 0.000000
# 21            ...                         0.000000                 0.000000
# 22            ...                        14.000000                 0.000000
# 23            ...                        14.000000                 0.000000
# 24            ...                         3.000000                 0.000000
# 25            ...                         7.000000                 0.000000
# 26            ...                         7.000000                 0.000000
# 28            ...                         1.500000                 0.000000
# 29            ...                        13.000000                 0.000000
# 32            ...                         0.000000                 0.000000
# 34            ...                         0.000000                 0.000000
# 35            ...                         0.000000                 0.000000
# 36            ...                         7.000000                 0.000000
# 37            ...                         0.000000                 0.000000
# 40            ...                         7.000000                 0.000000
# 41            ...                         4.500000                 0.000000
# 43            ...                         0.000000                 0.000000
# 44            ...                         4.500000                 1.500000
# 45            ...                         0.000000                 0.000000
# 46            ...                         5.500000                 1.500000
# ...           ...                              ...                      ...
# 228636        ...                         1.166667                 2.000000
# 228637        ...                         2.857143                 2.285714
# 228638        ...                         1.142857                 2.285714
# 228639        ...                         3.142857                 2.285714
# 228640        ...                         0.000000                 2.400000
# 228641        ...                         5.714286                 2.285714
# 228642        ...                         0.857143                 2.857143
# 228643        ...                         0.571429                 2.285714
# 228644        ...                         2.857143                 2.285714
# 228645        ...                         1.571429                 2.285714
# 228646        ...                         2.000000                 2.285714
# 228647        ...                         0.571429                 2.285714
# 228648        ...                         2.142857                 2.285714
# 228649        ...                         4.857143                 2.285714
# 228650        ...                         4.571429                 2.285714
# 228651        ...                         0.000000                 2.666667
# 228652        ...                         3.111111                 2.666667
# 228653        ...                         3.111111                 2.666667
# 228655        ...                         0.000000                 2.181818
# 228656        ...                         2.545455                 2.181818
# 228657        ...                         2.545455                 2.181818
# 228658        ...                         0.000000                 2.181818
# 228659        ...                         0.000000                 2.181818
# 228660        ...                         0.000000                 2.181818
# 228661        ...                         0.000000                 2.181818
# 228662        ...                         0.000000                 2.181818
# 228663        ...                         0.000000                 2.181818
# 228664        ...                         2.545455                 2.181818
# 228665        ...                         0.000000                 2.181818
# 228666        ...                         0.000000                 2.666667
#
#         avg s valence electrons  frac d valence electrons  \
# 1                      2.000000                  0.111111
# 3                      1.000000                  0.833333
# 4                      1.000000                  0.800000
# 5                      2.000000                  0.800000
# 6                      2.000000                  0.272727
# 8                      2.000000                  0.000000
# 9                      2.000000                  0.000000
# 11                     2.000000                  0.000000
# 13                     2.000000                  0.714286
# 17                     2.000000                  0.333333
# 18                     2.000000                  0.600000
# 21                     1.000000                  0.888889
# 22                     2.000000                  0.304348
# 23                     1.000000                  0.375000
# 24                     2.000000                  0.500000
# 25                     1.500000                  0.468750
# 26                     2.000000                  0.000000
# 28                     2.000000                  0.588235
# 29                     2.000000                  0.000000
# 32                     1.500000                  0.769231
# 34                     2.000000                  0.750000
# 35                     2.000000                  0.692308
# 36                     1.500000                  0.291667
# 37                     1.000000                  0.857143
# 40                     2.000000                  0.400000
# 41                     2.000000                  0.434783
# 43                     1.000000                  0.888889
# 44                     2.000000                  0.384615
# 45                     1.500000                  0.785714
# 46                     2.000000                  0.357143
# ...                         ...                       ...
# 228636                 1.666667                  0.000000
# 228637                 1.857143                  0.183333
# 228638                 2.000000                  0.073171
# 228639                 1.857143                  0.000000
# 228640                 1.800000                  0.176471
# 228641                 2.000000                  0.027778
# 228642                 2.000000                  0.000000
# 228643                 1.714286                  0.030303
# 228644                 2.000000                  0.152542
# 228645                 1.714286                  0.000000
# 228646                 1.714286                  0.142857
# 228647                 1.857143                  0.266667
# 228648                 2.000000                  0.000000
# 228649                 2.000000                  0.135135
# 228650                 1.714286                  0.240506
# 228651                 1.666667                  0.290909
# 228652                 1.666667                  0.211765
# 228653                 1.888889                  0.168675
# 228655                 1.545455                  0.280702
# 228656                 1.545455                  0.206897
# 228657                 1.727273                  0.053333
# 228658                 1.545455                  0.254545
# 228659                 1.727273                  0.122449
# 228660                 1.727273                  0.271186
# 228661                 1.727273                  0.245614
# 228662                 1.727273                  0.218182
# 228663                 1.545455                  0.196078
# 228664                 1.727273                  0.164706
# 228665                 1.727273                  0.085106
# 228666                 1.888889                  0.196078
#
#         frac f valence electrons  frac p valence electrons  \
# 1                       0.777778                  0.000000
# 3                       0.000000                  0.000000
# 4                       0.000000                  0.000000
# 5                       0.000000                  0.000000
# 6                       0.636364                  0.000000
# 8                       0.714286                  0.000000
# 9                       0.600000                  0.000000
# 11                      0.750000                  0.000000
# 13                      0.000000                  0.000000
# 17                      0.000000                  0.000000
# 18                      0.000000                  0.000000
# 21                      0.000000                  0.000000
# 22                      0.608696                  0.000000
# 23                      0.583333                  0.000000
# 24                      0.300000                  0.000000
# 25                      0.437500                  0.000000
# 26                      0.777778                  0.000000
# 28                      0.176471                  0.000000
# 29                      0.866667                  0.000000
# 32                      0.000000                  0.000000
# 34                      0.000000                  0.000000
# 35                      0.000000                  0.000000
# 36                      0.583333                  0.000000
# 37                      0.000000                  0.000000
# 40                      0.466667                  0.000000
# 41                      0.391304                  0.000000
# 43                      0.000000                  0.000000
# 44                      0.346154                  0.115385
# 45                      0.000000                  0.000000
# 46                      0.392857                  0.107143
# ...                          ...                       ...
# 228636                  0.241379                  0.413793
# 228637                  0.333333                  0.266667
# 228638                  0.195122                  0.390244
# 228639                  0.431373                  0.313725
# 228640                  0.000000                  0.470588
# 228641                  0.555556                  0.222222
# 228642                  0.150000                  0.500000
# 228643                  0.121212                  0.484848
# 228644                  0.338983                  0.271186
# 228645                  0.282051                  0.410256
# 228646                  0.285714                  0.326531
# 228647                  0.088889                  0.355556
# 228648                  0.333333                  0.355556
# 228649                  0.459459                  0.216216
# 228650                  0.405063                  0.202532
# 228651                  0.000000                  0.436364
# 228652                  0.329412                  0.282353
# 228653                  0.337349                  0.289157
# 228655                  0.000000                  0.421053
# 228656                  0.321839                  0.275862
# 228657                  0.373333                  0.320000
# 228658                  0.000000                  0.436364
# 228659                  0.000000                  0.489796
# 228660                  0.000000                  0.406780
# 228661                  0.000000                  0.421053
# 228662                  0.000000                  0.436364
# 32                    0.0
# 34                    1.0
# 35                    0.0
# 36                    0.0
# 37                    0.0
# 40                    0.0
# 41                    0.0
# 43                    0.0
# 44                    1.0
# 45                    0.0
# 46                    1.0
# ...                   ...
# 228636                0.0
# 228637                1.0
# 228638                0.0
# 228639                0.0
# 228640                1.0
# 228641                0.0
# 228642                1.0
# 228643                1.0
# 228644                0.0
# 228645                0.0
# 228646                0.0
# 228647                0.0
# 228648                0.0
# 228649                0.0
# 228650                1.0
# 228651                0.0
# 228652                0.0
# 228653                0.0
# 228655                0.0
# 228656                0.0
# 228657                0.0
# 228658                0.0
# 228659                0.0
# 228660                0.0
# 228661                0.0
# 228662                0.0
# 228663                0.0
# 228664                0.0
# 228665                0.0
# 228666                0.0
#
# [117454 rows x 158 columns]

# %%
#Band gap data
bandgaps = np.array(training_set_use["bandgap"], dtype=float)
print bandgaps

#Band gap range data
bg_range = np.zeros(np.shape(bandgaps), dtype=str)
for i in range(len(bandgaps)):
    if bandgaps[i] == 0:
        bg_range[i] = "0"
    elif bandgaps[i] > 0 and bandgaps[i] < 1.5:
        bg_range[i] = "1"
    elif bandgaps[i] >= 1.5 and bandgaps[i] < 3.0:
        bg_range[i] = "2"
    elif bandgaps[i] >= 3.0:
        bg_range[i] = "3"
# Out:
# [ 0.  0.  0. ...,  0.  0.  0.]

# %% [markdown]
# ### Predict band gap range using classifiers

# %%
model1 = RandomForestClassifier(n_estimators=10, criterion="gini", min_samples_split=2)
model1.fit(training_set_use[attr_names], bg_range)
prediction = model1.predict(training_set_use[attr_names])

# %%
pd.crosstab(bg_range, prediction, rownames=["actual"], colnames=["predicted"])
# Out:
# predicted       0     1     2    3
# actual
# 0          113259     4     5    2
# 1              80  1756     7    0
# 2              14     5  1488    3
# 3               4     2     5  820

# %%
model2 = DecisionTreeClassifier()
model2.fit(training_set_use[attr_names], bg_range)
prediction = model2.predict(training_set_use[attr_names])

# %%
pd.crosstab(bg_range, prediction, rownames=["actual"], colnames=["predicted"])
# Out:
# predicted       0     1     2    3
# actual
# 0          113270     0     0    0
# 1               0  1843     0    0
# 2               0     0  1510    0
# 3               0     0     0  831

# %%
rf_model = RandomForestRegressor()
rf_model.fit(training_set_use[attr_names], bandgaps)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_split=1e-07, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=10, n_jobs=1, oob_score=False, random_state=None,
#            verbose=0, warm_start=False)

# %%
prediction = rf_model.predict(training_set_use[attr_names])

# %%
plt.scatter(bandgaps, prediction)
plt.plot(range(11), range(11), 'r')
plt.xlabel("OQMD Data")
plt.ylabel("Predicted")

# %%
# %%time

errors = cross_val_score(RandomForestRegressor(), training_set_use[attr_names], bandgaps, scoring="neg_mean_absolute_error", cv=10)
mae = np.mean(np.abs(errors))

print mae
# Out:
# 0.0560449502013
# CPU times: user 10min 57s, sys: 1.19 s, total: 10min 58s
# Wall time: 10min 59s

# %% [markdown]
# ### Decision Tree Regressor

# %%
dt_model = DecisionTreeRegressor()
dt_model.fit(training_set_use[attr_names], bandgaps)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#            max_leaf_nodes=None, min_impurity_split=1e-07,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#            splitter='best')

# %%
dt_prediction = dt_model.predict(training_set_use[attr_names])

# %%
plt.scatter(bandgaps, dt_prediction)
plt.plot(range(11), range(11), 'r')
plt.xlabel("OQMD Data")
plt.ylabel("Predicted")

# %%
# %%time

errors = cross_val_score(DecisionTreeRegressor(), training_set_use[attr_names], bandgaps, scoring="neg_mean_absolute_error", cv=10)
mae = np.mean(np.abs(errors))

print mae
# Out:
# 0.0600166032497
# CPU times: user 1min 47s, sys: 712 ms, total: 1min 47s
# Wall time: 1min 48s
