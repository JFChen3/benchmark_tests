# %% [markdown]
# # Glass Formation Prediction based *Ward 2016*
#
# This notebook uses the method from [Ward 2016](https://www.nature.com/articles/npjcompumats201628) to predict glass formation of compounds. Specifically, it uses the set of composition based attributes described in the paper to train a machine learning model.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import matminer

from pymatgen import Composition
from matminer.descriptors import composition_features as cp
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor
from sklearn.model_selection import cross_val_score, KFold

# %matplotlib inline

# %% [markdown]
# ## Load training data and compute descriptors
# The training data consists of 6836 compounds classified by whether they have amorphous (AM), partially amorphous (AC), or crystalline (CR) structures.

# %%
training_set = pd.read_csv("datasets/glass.data", sep=' ')
training_set
# Out:
#               comp gfa{AM,AC,CR}
# 0     Ag20Al25La55            AM
# 1     Ag15Al10Mg75            AM
# 2     Ag25Al10Mg65            AM
# 3     Ag25Al20Mg55            AM
# 4     Ag35Al10Mg55            AM
# 5     Ag35Al20Mg45            AM
# 6     Ag45Al20Mg35            AM
# 7      Ag10Ce6Cu84            AM
# 8     Ag10Ce10Cu80            AM
# 9      Ag15Ce6Cu79            AM
# 10     Ag20Ce6Cu74            AM
# 11    Ag20Ce10Cu70            AM
# 12     Ag25Ce6Cu69            AM
# 13     Ag30Ce6Cu64            AM
# 14    Ag30Ce10Cu60            AM
# 15     Ag35Ce4Cu61            AM
# 16     Ag35Ce5Cu60            AM
# 17     Ag35Ce6Cu59            AM
# 18     Ag40Ce3Cu57            AM
# 19     Ag40Ce4Cu56            AM
# 20     Ag40Ce5Cu55            AM
# 21     Ag40Ce8Cu52            AM
# 22    Ag40Ce10Cu50            AM
# 23     Ag45Ce3Cu52            AM
# 24     Ag45Ce4Cu51            AM
# 25     Ag45Ce5Cu50            AM
# 26     Ag50Ce3Cu47            AM
# 27     Ag50Ce4Cu46            AM
# 28     Ag50Ce5Cu45            AM
# 29    Ag50Ce10Cu40            AM
# ...            ...           ...
# 6806  Si60Ti20Zr20            AM
# 6807  Si60Ti24Zr16            AM
# 6808  Si65Ti10Zr25            AM
# 6809  Si65Ti15Zr20            AM
# 6810  Si65Ti20Zr15            AM
# 6811  Si65Ti23Zr12            AM
# 6812  Si70Ti11Zr19            AM
# 6813  Si70Ti15Zr15            AM
# 6814  Si70Ti20Zr10            AM
# 6815   Si70Ti22Zr8            AM
# 6816  Si75Ti12Zr13            AM
# 6817  Si75Ti15Zr10            AM
# 6818   Si75Ti20Zr5            AM
# 6819   Si75Ti22Zr3            AM
# 6820   Si80Ti14Zr6            AM
# 6821   Si80Ti15Zr5            AM
# 6822   Si80Ti20Zr0            AM
# 6823   Si85Ti15Zr0            AM
# 6824   Si0Ti90Zr10            CR
# 6825   Si82Ti8Zr10            CR
# 6826   Si84Ti6Zr10            CR
# 6827   Si86Ti4Zr10            CR
# 6828   Si88Ti2Zr10            CR
# 6829    Si15V0Zr85            AM
# 6830   Si15V10Zr75            AM
# 6831   Si15V20Zr65            AM
# 6832   Si15V30Zr55            AM
# 6833   Si15V40Zr45            AM
# 6834    Si15W0Zr85            AM
# 6835   Si15W10Zr75            AM
#
# [6836 rows x 2 columns]

# %% [markdown]
# ## Create PyMatGen Composition objects

# %%
comp_objects = [Composition(comp) for comp in training_set["comp"]]
comp_objects
training_set = training_set.assign(comp_obj=comp_objects)
training_set
# Out:
#               comp gfa{AM,AC,CR}      comp_obj
# 0     Ag20Al25La55            AM  (La, Al, Ag)
# 1     Ag15Al10Mg75            AM  (Mg, Al, Ag)
# 2     Ag25Al10Mg65            AM  (Mg, Al, Ag)
# 3     Ag25Al20Mg55            AM  (Mg, Al, Ag)
# 4     Ag35Al10Mg55            AM  (Mg, Al, Ag)
# 5     Ag35Al20Mg45            AM  (Mg, Al, Ag)
# 6     Ag45Al20Mg35            AM  (Mg, Al, Ag)
# 7      Ag10Ce6Cu84            AM  (Ce, Cu, Ag)
# 8     Ag10Ce10Cu80            AM  (Ce, Cu, Ag)
# 9      Ag15Ce6Cu79            AM  (Ce, Cu, Ag)
# 10     Ag20Ce6Cu74            AM  (Ce, Cu, Ag)
# 11    Ag20Ce10Cu70            AM  (Ce, Cu, Ag)
# 12     Ag25Ce6Cu69            AM  (Ce, Cu, Ag)
# 13     Ag30Ce6Cu64            AM  (Ce, Cu, Ag)
# 14    Ag30Ce10Cu60            AM  (Ce, Cu, Ag)
# 15     Ag35Ce4Cu61            AM  (Ce, Cu, Ag)
# 16     Ag35Ce5Cu60            AM  (Ce, Cu, Ag)
# 17     Ag35Ce6Cu59            AM  (Ce, Cu, Ag)
# 18     Ag40Ce3Cu57            AM  (Ce, Cu, Ag)
# 19     Ag40Ce4Cu56            AM  (Ce, Cu, Ag)
# 20     Ag40Ce5Cu55            AM  (Ce, Cu, Ag)
# 21     Ag40Ce8Cu52            AM  (Ce, Cu, Ag)
# 22    Ag40Ce10Cu50            AM  (Ce, Cu, Ag)
# 23     Ag45Ce3Cu52            AM  (Ce, Cu, Ag)
# 24     Ag45Ce4Cu51            AM  (Ce, Cu, Ag)
# 25     Ag45Ce5Cu50            AM  (Ce, Cu, Ag)
# 26     Ag50Ce3Cu47            AM  (Ce, Cu, Ag)
# 27     Ag50Ce4Cu46            AM  (Ce, Cu, Ag)
# 28     Ag50Ce5Cu45            AM  (Ce, Cu, Ag)
# 29    Ag50Ce10Cu40            AM  (Ce, Cu, Ag)
# ...            ...           ...           ...
# 6806  Si60Ti20Zr20            AM  (Zr, Ti, Si)
# 6807  Si60Ti24Zr16            AM  (Zr, Ti, Si)
# 6808  Si65Ti10Zr25            AM  (Zr, Ti, Si)
# 6809  Si65Ti15Zr20            AM  (Zr, Ti, Si)
# 6810  Si65Ti20Zr15            AM  (Zr, Ti, Si)
# 6811  Si65Ti23Zr12            AM  (Zr, Ti, Si)
# 6812  Si70Ti11Zr19            AM  (Zr, Ti, Si)
# 6813  Si70Ti15Zr15            AM  (Zr, Ti, Si)
# 6814  Si70Ti20Zr10            AM  (Zr, Ti, Si)
# 6815   Si70Ti22Zr8            AM  (Zr, Ti, Si)
# 6816  Si75Ti12Zr13            AM  (Zr, Ti, Si)
# 6817  Si75Ti15Zr10            AM  (Zr, Ti, Si)
# 6818   Si75Ti20Zr5            AM  (Zr, Ti, Si)
# 6819   Si75Ti22Zr3            AM  (Zr, Ti, Si)
# 6820   Si80Ti14Zr6            AM  (Zr, Ti, Si)
# 6821   Si80Ti15Zr5            AM  (Zr, Ti, Si)
# 6822   Si80Ti20Zr0            AM      (Ti, Si)
# 6823   Si85Ti15Zr0            AM      (Ti, Si)
# 6824   Si0Ti90Zr10            CR      (Zr, Ti)
# 6825   Si82Ti8Zr10            CR  (Zr, Ti, Si)
# 6826   Si84Ti6Zr10            CR  (Zr, Ti, Si)
# 6827   Si86Ti4Zr10            CR  (Zr, Ti, Si)
# 6828   Si88Ti2Zr10            CR  (Zr, Ti, Si)
# 6829    Si15V0Zr85            AM      (Zr, Si)
# 6830   Si15V10Zr75            AM   (Zr, Si, V)
# 6831   Si15V20Zr65            AM   (Zr, Si, V)
# 6832   Si15V30Zr55            AM   (Zr, Si, V)
# 6833   Si15V40Zr45            AM   (Zr, Si, V)
# 6834    Si15W0Zr85            AM      (Zr, Si)
# 6835   Si15W10Zr75            AM   (Zr, W, Si)
#
# [6836 rows x 3 columns]

# %% [markdown]
# ## Compute descriptors using MatMiner
# Here, we compute 145 composition based attributes as described in *Ward 2016*.

# %%
# %%time

def calc_attributes(training_set):
    not_attr = list(training_set) #Non-attribute columns
    training_set_updated = cp.StoichAttribute().featurize_dataframe(training_set, col_id="comp_obj")
    training_set_updated = cp.ElemPropertyAttribute().featurize_dataframe(training_set_updated, col_id="comp_obj")
    training_set_updated = cp.ValenceOrbitalAttribute().featurize_dataframe(training_set_updated, col_id="comp_obj")
    training_set_updated = cp.IonicAttribute().featurize_dataframe(training_set_updated, col_id="comp_obj")
    all_cols = list(training_set_updated)
    attr_names = [col for col in all_cols if col not in not_attr]
    return training_set_updated, attr_names

all_descriptors, attr_names = calc_attributes(training_set)
print np.shape(all_descriptors)
# Out:
# (6836, 152)
# CPU times: user 20.7 s, sys: 230 ms, total: 20.9 s
# Wall time: 20.9 s

# %% [markdown]
# ## Prediction of glass formation
#
# A random forest classifier model is trained and used to predict glass formation.

# %%
gfa = all_descriptors["gfa{AM,AC,CR}"]

model1 = RandomForestClassifier()
model1.fit(all_descriptors[attr_names], gfa)
prediction = model1.predict(all_descriptors[attr_names])

# %% [markdown]
# Comparison of actual vs predicted structures. We can see that most of the compounds were classified properly.

# %%
pd.crosstab(gfa, prediction, rownames=["actual"], colnames=["predicted"])
# Out:
# predicted   AC    AM    CR
# actual
# AC         677    28    15
# AM          12  4839    17
# CR          21    37  1190
