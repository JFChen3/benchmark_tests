# %% [markdown]
# # Formation Energy Prediction using *Deml 2016* Descriptors
#
# This notebook uses the method from [Deml 2016](https://journals.aps.org/prb/abstract/10.1103/PhysRevB.93.085142) to predict formation energy of compounds. Specifically, it uses the set of composition based attributes described in the paper to train a machine learning model.

# %%
import numpy as np
import matplotlib.pyplot as plt
import re
import itertools
import pandas as pd
import matminer

from pymatgen import Composition

# %matplotlib inline

# %% [markdown]
# ## Load input files and generate descriptors
# The training set is a set of ~2000 compounds with data extracted from the Open Quantum Materials Database (OQMD)

# %%
training_set = pd.read_csv("datasets/deml_dataset.csv")
training_set
# Out:
#              composition   delta_e
# 0                  As1Y1 -1.555732
# 1                  Ga1P1 -0.534169
# 2               Ga2Mg1S4 -1.068504
# 3             Cd4K1O12V3 -1.968765
# 4     Al1Ca1Fe1Na1O12Si4 -2.949067
# 5               Hf1O3Pb1 -2.830320
# 6        Al2Ba2Co1F14Mn1 -3.488390
# 7        Ba2Cd1F14Fe2Mn1 -3.007836
# 8               Be2O4Si1 -3.020793
# 9        Ba2Ca1Cu1F14Ga2 -3.325601
# 10              Ge1O4Zn2 -1.809053
# 11           Ca1Cr1F7Sr1 -3.707430
# 12             As3Ga1Na6 -0.523152
# 13              Ga1Na6P3 -0.548523
# 14       Al2Ba2Cu1F14Mn1 -3.463375
# 15              O4Si1Zn2 -2.286625
# 16              Al2Ca1O4 -3.293900
# 17           K3Nb3O13Si2 -2.818445
# 18                Ga1Sb1 -0.167088
# 19              Ba1O4Sc2 -3.534127
# 20          Ge3Na4O12Zr2 -2.477888
# 21          Ba3In2O11Zn5 -2.038818
# 22             Ba1Mn1Sb2 -0.452687
# 23              Ge4O9Sr1 -2.158955
# 24           Ba1Co1O4Si1 -2.518078
# 25           Ge2K3Nb3O13 -2.469440
# ...

# %% [markdown]
# ### Create PyMatGen composition objects

# %%
comp_objects = [Composition(comp) for comp in training_set["composition"]]
comp_objects
training_set = training_set.assign(comp_obj=comp_objects)
training_set
# Out:
#              composition   delta_e                 comp_obj
# 0                  As1Y1 -1.555732                  (As, Y)
# 1                  Ga1P1 -0.534169                  (Ga, P)
# 2               Ga2Mg1S4 -1.068504              (S, Mg, Ga)
# 3             Cd4K1O12V3 -1.968765            (O, Cd, K, V)
# 4     Al1Ca1Fe1Na1O12Si4 -2.949067  (O, Na, Al, Si, Ca, Fe)
# 5               Hf1O3Pb1 -2.830320              (Hf, O, Pb)
# 6        Al2Ba2Co1F14Mn1 -3.488390      (Ba, F, Co, Al, Mn)
# 7        Ba2Cd1F14Fe2Mn1 -3.007836      (Ba, F, Fe, Cd, Mn)
# 8               Be2O4Si1 -3.020793              (O, Be, Si)
# 9        Ba2Ca1Cu1F14Ga2 -3.325601      (Ba, F, Ca, Cu, Ga)
# 10              Ge1O4Zn2 -1.809053              (Ge, O, Zn)
# 11           Ca1Cr1F7Sr1 -3.707430          (Cr, F, Ca, Sr)
# 12             As3Ga1Na6 -0.523152             (As, Na, Ga)
# 13              Ga1Na6P3 -0.548523              (P, Na, Ga)
# 14       Al2Ba2Cu1F14Mn1 -3.463375      (Ba, Mn, Cu, Al, F)
# ...

# %% [markdown]
# ## Compute descriptors using MatMiner
# Here, we compute composition based attributes as described in *Deml 2016* using the [MatMiner](https://github.com/hackingmaterials/matminer) implementation of the featurizer.

# %%
from matminer.descriptors import composition_features as cp

import time
start = time.time()
def calc_attributes(training_set):
    training_set_updated = cp.StoichAttributes(p_list=None, num_atoms=True).featurize_dataframe(training_set, col_id="comp_obj")
    training_set_updated = cp.ElemPropertyAttributes(method="deml").featurize_dataframe(training_set_updated, col_id="comp_obj")
    training_set_updated = cp.ValenceOrbitalAttributes(orbitals=["s","p","d"], props=["avg","frac"]).featurize_dataframe(training_set_updated, col_id="comp_obj")
    training_set_updated = cp.TMetalFractionAttribute().featurize_dataframe(training_set_updated, col_id="comp_obj")
    training_set_updated = cp.ElectronAffinityAttribute().featurize_dataframe(training_set_updated, col_id="comp_obj")
    training_set_updated = cp.ElectronegativityDiffAttribute().featurize_dataframe(training_set_updated, col_id="comp_obj")
    training_set_updated = cp.TMetalFractionAttribute().featurize_dataframe(training_set_updated, col_id="comp_obj")
    training_set_updated = cp.FERECorrectionAttribute().featurize_dataframe(training_set_updated, col_id="comp_obj")
    return training_set_updated

#%lprun -f calc_attributes calc_attributes()

all_descriptors = calc_attributes(training_set)
print all_descriptors
print "Featurization time: %f "%(time.time() - start)
# Out:
#              composition   delta_e                 comp_obj  Number of atoms  \
# 0                  As1Y1 -1.555732                  (As, Y)              2.0
# 1                  Ga1P1 -0.534169                  (Ga, P)              2.0
# 2               Ga2Mg1S4 -1.068504              (S, Mg, Ga)              2.0
# 3             Cd4K1O12V3 -1.968765            (O, Cd, K, V)              2.0
# 4     Al1Ca1Fe1Na1O12Si4 -2.949067  (O, Na, Al, Si, Ca, Fe)              2.0
# 5               Hf1O3Pb1 -2.830320              (Hf, O, Pb)              2.0
# 6        Al2Ba2Co1F14Mn1 -3.488390      (Ba, F, Co, Al, Mn)              2.0
# 7        Ba2Cd1F14Fe2Mn1 -3.007836      (Ba, F, Fe, Cd, Mn)              2.0
# 8               Be2O4Si1 -3.020793              (O, Be, Si)              2.0
# 9        Ba2Ca1Cu1F14Ga2 -3.325601      (Ba, F, Ca, Cu, Ga)              2.0
# 10              Ge1O4Zn2 -1.809053              (Ge, O, Zn)              2.0
# ...

# %% [markdown]
# ## Predicting formation energy

# %%
training_set_use = all_descriptors.replace("None", np.nan)
training_set_use = all_descriptors.replace(np.inf, np.nan)
training_set_use = training_set_use.dropna()

training_set_use
# Out:
#              composition   delta_e                 comp_obj  Number of atoms  \
# 0                  As1Y1 -1.555732                  (As, Y)              2.0
# 1                  Ga1P1 -0.534169                  (Ga, P)              2.0
# 2               Ga2Mg1S4 -1.068504              (S, Mg, Ga)              2.0
# 3             Cd4K1O12V3 -1.968765            (O, Cd, K, V)              2.0
# 4     Al1Ca1Fe1Na1O12Si4 -2.949067  (O, Na, Al, Si, Ca, Fe)              2.0
# 6        Al2Ba2Co1F14Mn1 -3.488390      (Ba, F, Co, Al, Mn)              2.0
# 7        Ba2Cd1F14Fe2Mn1 -3.007836      (Ba, F, Fe, Cd, Mn)              2.0
# 8               Be2O4Si1 -3.020793              (O, Be, Si)              2.0
# 9        Ba2Ca1Cu1F14Ga2 -3.325601      (Ba, F, Ca, Cu, Ga)              2.0
# 10              Ge1O4Zn2 -1.809053              (Ge, O, Zn)              2.0
# 11           Ca1Cr1F7Sr1 -3.707430          (Cr, F, Ca, Sr)              2.0
# ...

# %%
#Band gap data
delta_e = np.array(training_set_use["delta_e"], dtype=float)
print delta_e

#Energy range data
delta_e = np.array(training_set_use["delta_e"], dtype=float)

energy_range = np.zeros(np.shape(delta_e), dtype=str)
for i in range(len(delta_e)):
    if delta_e[i] < 0:
        energy_range[i] = "neg"
    else:
        energy_range[i] = "pos"
        
print energy_range
# Out:
# [-1.55573181 -0.53416896 -1.06850412 ...,  0.46489684 -4.07700786 -2.733333  ]
# ['n' 'n' 'n' ..., 'p' 'n' 'n']

# %% [markdown]
# ### Predict formation energy range using classifiers

# %%
cols_to_drop = ["composition", "comp_obj", "delta_e"]

# %%
#Classifier step
from sklearn.ensemble import RandomForestClassifier

model1 = RandomForestClassifier(n_estimators=10, criterion="gini", min_samples_split=2)
model1.fit(training_set_use.drop(cols_to_drop, axis=1), energy_range)
prediction = model1.predict(training_set_use.drop(cols_to_drop, axis=1))

# %%
pd.crosstab(energy_range, prediction, rownames=["actual"], colnames=["predicted"])
# Out:
# predicted     n  p
# actual
# n          2035  0
# p             4  9

# %%
#Classifier step
from sklearn.tree import DecisionTreeClassifier

model2 = DecisionTreeClassifier()
model2.fit(training_set_use.drop(cols_to_drop, axis=1), energy_range)
prediction = model2.predict(training_set_use.drop(cols_to_drop, axis=1))

# %%
pd.crosstab(energy_range, prediction, rownames=["actual"], colnames=["predicted"])
# Out:
# predicted     n   p
# actual
# n          2035   0
# p             0  13

# %%
from sklearn.ensemble import RandomForestRegressor

rf_model = RandomForestRegressor()
rf_model.fit(training_set_use.drop(cols_to_drop, axis=1), delta_e)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_split=1e-07, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=10, n_jobs=1, oob_score=False, random_state=None,
#            verbose=0, warm_start=False)

# %%
prediction = rf_model.predict(training_set_use.drop(cols_to_drop, axis=1))

# %%
plt.scatter(delta_e, prediction)
plt.plot(range(-5,2), range(-5,2), 'r')
plt.xlabel("OQMD Data")
plt.ylabel("Predicted")

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold

cv_start = time.time()

errors = cross_val_score(RandomForestRegressor(), training_set_use.drop(cols_to_drop, axis=1), delta_e, scoring="neg_mean_absolute_error", cv=10)
mae = np.mean(np.abs(errors))

print mae
print "Cross-validation time: %f"%(time.time()-cv_start)
# Out:
# 0.115149662051
# Cross-validation time: 6.434867

# %% [markdown]
# ### Decision Tree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor

dt_model = DecisionTreeRegressor()
dt_model.fit(training_set_use.drop(cols_to_drop, axis=1), delta_e)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#            max_leaf_nodes=None, min_impurity_split=1e-07,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#            splitter='best')

# %%
dt_prediction = dt_model.predict(training_set_use.drop(cols_to_drop, axis=1))

# %%
plt.scatter(delta_e, dt_prediction)
plt.plot(range(-5,2), range(-5,2), 'r')
plt.xlabel("OQMD Data")
plt.ylabel("Predicted")

# %%
cv_start = time.time()

errors = cross_val_score(DecisionTreeRegressor(), training_set_use.drop(cols_to_drop, axis=1), delta_e, scoring="neg_mean_absolute_error", cv=10)
mae = np.mean(np.abs(errors))

print mae
print "Cross-validation time: %f"%(time.time()-cv_start)
# Out:
# 0.162127754574
# Cross-validation time: 1.043570
